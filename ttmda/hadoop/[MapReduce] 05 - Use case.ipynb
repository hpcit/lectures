# %% [markdown]
# # A real use case

# %% [markdown]
# ![ngs sequencing](http://www.genohm.com/wp-content/uploads/2015/05/DNA-actg1.jpg)

# %% [markdown]
# ## Preparation

# %%
# Base dir
mydir = './tmp/'
# Python variables
myfile = mydir + 'job.py'
myinput = mydir + 'ngs.sam'
myshortinput = myinput + '.short'
ngs_module = mydir + 'ngs.py'
# Bash variables
# %env mydir $mydir
# %env myinput $myinput
# %env myshortinput $myshortinput
# Out:
# env: mydir=./tmp/
# env: myinput=./tmp/ngs.sam
# env: myshortinput=./tmp/ngs.sam.short

# %%
# %%bash
# mkdir -p $mydir
# head -1500 $myinput > $myshortinput
# wc -l $mydir*sam*
# Out:
#    334121 ./tmp/ngs.sam
#      1500 ./tmp/ngs.sam.short
#    335621 total

# %% [markdown]
# ## Constants

# %%
# %%writefile $ngs_module
# #!/usr/bin/env python3
# # -*- coding: utf-8 -*-
#
# """ NGS functions """
#
# # Symbol for header inside SAM format
# HEADER_CHAR = "@"
# # Chromosomic separator
# SEP = ":"
# # Formats for quality reading: http://j.mp/1zo30bt
# # Illumina 1.8+ Phred+33,  raw reads typically (0, 41)
# PHRED_INIT = 33
# # What is the minimum quality?
# PHRED_THOLD = 20  # Handle STRAND:
# FORWARD_STRAND_FLAG = 16
# Out:
# Overwriting ./tmp/ngs.py

# %% [markdown]
# Handling the strand

# %%
# %%writefile -a $ngs_module
#
# def compute_strand(flag, myseq='ACTG', mystart=1):
#     # Convert the flag to decimal, and check
#     # the bit in the 5th position from the right.
#     if flag & FORWARD_STRAND_FLAG:       # Strand forward
#         mystop = mystart + len(myseq)
#     else:               # Strand reverse
#         mystop = mystart + 1
#         mystart = mystop - len(myseq)
#     return mystart, mystop
# Out:
# Appending to ./tmp/ngs.py

# %% [markdown]
# Generating ngs data from one line

# %%
# %%writefile -a $ngs_module
#
# def ngs_split(line=None):
#     """ Recover necessary data for NGS analysis """
#     pieces = line.split("\t")
#
#     myflag = int(pieces[1])
#     mychr = pieces[2]
#     mystart = int(pieces[3])
#     myseq = pieces[9]
#     myqc = pieces[10]
#     mystart, mystop = compute_strand(myflag, myseq, mystart)
#
#     if isinstance(mychr[3:], int):
#         code = int(mychr[3:]).zfill(2)  # sortable chromosome code
#     else:
#         code = ord(mychr[3:]).__str__()
#
#     return mychr, mystart, mystop, myseq, myflag, myqc, code
# Out:
# Appending to ./tmp/ngs.py

# %%
cat $ngs_module
# Out:
# #!/usr/bin/env python3
# # -*- coding: utf-8 -*-
#
# """ NGS functions """
#
# # Symbol for header inside SAM format
# HEADER_CHAR = "@"
# # Chromosomic separator
# SEP = ":"
# # Formats for quality reading: http://j.mp/1zo30bt
# # Illumina 1.8+ Phred+33,  raw reads typically (0, 41)
# PHRED_INIT = 33
# # What is the minimum quality?
# PHRED_THOLD = 20  # Handle STRAND:
# FORWARD_STRAND_FLAG = 16
#
# def compute_strand(flag, myseq='ACTG', mystart=1):
#     # Convert the flag to decimal, and check
#     # the bit in the 5th position from the right.
#     if flag & FORWARD_STRAND_FLAG:       # Strand forward
#         mystop = mystart + len(myseq)
#     else:               # Strand reverse
#         mystop = mystart + 1
#         mystart = mystop - len(myseq)
#     return mystart, mystop
#
# def ngs_split(line=None):
#     """ Recover necessary data for NGS analysis """
#     pieces = line.split("\t")
#
#     myflag = int(pieces[1])
#     mychr = pieces[2]
#     mystart = int(pieces[3])
#     myseq = pieces[9]
#     myqc = pieces[10]
#     mystart, mystop = compute_strand(myflag, myseq, mystart)
#
#     if isinstance(mychr[3:], int):
#         code = int(mychr[3:]).zfill(2)  # sortable chromosome code
#     else:
#         code = ord(mychr[3:]).__str__()
#
#     return mychr, mystart, mystop, myseq, myflag, myqc, code

# %%
# %%writefile $myfile
#
# from mrjob.job import MRJob
# from ngs import ngs_split, \
#     PHRED_INIT, PHRED_THOLD, HEADER_CHAR, SEP
#
# class MRcoverage(MRJob):
#     """ Map Reduce for NGS coverage computation"""
#
#     def mapper(self, _, line):
#         """ Split data into keys and value """
#
#         if line[0] == HEADER_CHAR:
#             yield "header", 1
#         else:
#             # Get data
#             mychr, mystart, mystop, myseq, myflag, myqc, code = ngs_split(line)
#             # For each base of my dna sequence
#             for i in range(mystart, mystop):
#                 mypos = i - mystart
#                 current_qc = ord(myqc[mypos]) - PHRED_INIT  # quality value
#                 if current_qc > PHRED_THOLD:
#                     # Choose the key to emit
#                     label = code + SEP + i.__str__() + SEP + mychr
#                     current_letter = myseq[mypos]
#                     yield label, 1
#                     yield label + SEP + current_letter, 1
#
#     def reducer(self, key, values):
#         """ Sum up values"""
#         yield key, sum(values)
#
# if __name__ == '__main__':
#     MRcoverage().run()
# Out:
# Overwriting ./tmp/job.py

# %%
# %system python $myfile $myshortinput
# Out:
# ['no configs found; falling back on auto-configuration',
#  'no configs found; falling back on auto-configuration',
#  'creating tmp directory /tmp/job.jovyan.20151214.162912.231757',
#  'writing to /tmp/job.jovyan.20151214.162912.231757/step-0-mapper_part-00000',
#  'Counters from step 1:',
#  '  (none found)',
#  'writing to /tmp/job.jovyan.20151214.162912.231757/step-0-mapper-sorted',
#  '> sort /tmp/job.jovyan.20151214.162912.231757/step-0-mapper_part-00000',
#  'writing to /tmp/job.jovyan.20151214.162912.231757/step-0-reducer_part-00000',
#  'Counters from step 1:',
#  '  (none found)',
#  'Moving /tmp/job.jovyan.20151214.162912.231757/step-0-reducer_part-00000 -> /tmp/job.jovyan.20151214.162912.231757/output/part-00000',
#  'Streaming final output from /tmp/job.jovyan.20151214.162912.231757/output',
#  '"49:10000:chr1"\t2',
#  '"49:10000:chr1:A"\t2',
#  '"49:10001:chr1"\t2',
#  '"49:10001:chr1:C"\t2',
#  '"49:10002:chr1"\t2',
#  '"49:10002:chr1:A"\t2',
#  '"49:10003:chr1"\t2',
#  '"49:10003:chr1:G"\t2',
#  '"49:10004:chr1"\t2',
#  '"49:10004:chr1:C"\t2',
#  '"49:10005:chr1"\t2',
#  '"49:10005:chr1:C"\t2',
#  '"49:10006:chr1"\t2',
#  '"49:10006:chr1:C"\t2',
#  '"49:10007:chr1"\t2',
#  '"49:10007:chr1:T"\t2',
#  '"49:10008:chr1"\t2',
#  '"49:10008:chr1:A"\t2',
#  '"49:10009:chr1"\t2',
#  '"49:10009:chr1:A"\t2',
#  '"49:10010:chr1"\t2',
#  '"49:10010:chr1:C"\t2',
#  '"49:10011:chr1"\t2',
#  '"49:10011:chr1:C"\t2',
#  '"49:10012:chr1"\t2',
#  '"49:10012:chr1:C"\t2',
#  '"49:10013:chr1"\t2',
#  '"49:10013:chr1:T"\t2',
#  '"49:10014:chr1"\t2',
#  '"49:10014:chr1:A"\t2',
#  '"49:10015:chr1"\t2',
#  '"49:10015:chr1:A"\t2',
#  '"49:10016:chr1"\t2',
#  '"49:10016:chr1:C"\t2',
#  '"49:10017:chr1"\t2',
#  '"49:10017:chr1:C"\t2',
#  '"49:10018:chr1"\t2',
#  '"49:10018:chr1:C"\t2',
#  '"49:10019:chr1"\t2',
#  '"49:10019:chr1:T"\t2',
#  '"49:10020:chr1"\t2',
#  '"49:10020:chr1:A"\t2',
#  '"49:10021:chr1"\t2',
#  '"49:10021:chr1:A"\t2',
#  '"49:100224257:chr1"\t1',
#  '"49:100224257:chr1:G"\t1',
#  '"49:100224258:chr1"\t1',
#  '"49:100224258:chr1:G"\t1',
#  '"49:100224259:chr1"\t1',
#  '"49:100224259:chr1:G"\t1',
#  '"49:100224260:chr1"\t1',
#  '"49:100224260:chr1:A"\t1',
#  '"49:100224261:chr1"\t1',
#  '"49:100224261:chr1:A"\t1',
#  '"49:100224262:chr1"\t1',
#  '"49:100224262:chr1:G"\t1',
#  '"49:100224263:chr1"\t1',
#  '"49:100224263:chr1:A"\t1',
#  '"49:100224264:chr1"\t1',
#  '"49:100224264:chr1:T"\t1',
#  '"49:100224265:chr1"\t1',
#  '"49:100224265:chr1:A"\t1',
#  '"49:100224266:chr1"\t1',
#  '"49:100224266:chr1:T"\t1',
#  '"49:100224267:chr1"\t1',
#  '"49:100224267:chr1:C"\t1',
#  '"49:100224268:chr1"\t1',
#  '"49:100224268:chr1:G"\t1',
#  '"49:100224269:chr1"\t1',
#  '"49:100224269:chr1:C"\t1',
#  '"49:100224270:chr1"\t1',
#  '"49:100224270:chr1:T"\t1',
#  '"49:100224271:chr1"\t1',
#  '"49:100224271:chr1:A"\t1',
#  '"49:100224272:chr1"\t1',
#  '"49:100224272:chr1:A"\t1',
#  '"49:100224273:chr1"\t1',
#  '"49:100224273:chr1:A"\t1',
#  '"49:100224274:chr1"\t1',
#  '"49:100224274:chr1:T"\t1',
#  '"49:100224275:chr1"\t1',
#  '"49:100224275:chr1:T"\t1',
#  '"49:100224276:chr1"\t1',
#  '"49:100224276:chr1:C"\t1',
#  '"49:100224277:chr1"\t1',
#  '"49:100224277:chr1:T"\t1',
#  '"49:100224278:chr1"\t1',
#  '"49:100224278:chr1:T"\t1',
#  '"49:100224279:chr1"\t1',
#  '"49:100224279:chr1:T"\t1',
#  '"49:100224280:chr1"\t1',
#  '"49:100224280:chr1:T"\t1',
#  '"49:100224281:chr1"\t1',
#  '"49:100224281:chr1:C"\t1',
#  '"49:100224282:chr1"\t1',
#  '"49:100224282:chr1:C"\t1',
#  '"49:100224283:chr1"\t1',
#  '"49:100224283:chr1:T"\t1',
#  '"49:100224284:chr1"\t1',
#  '"49:100224284:chr1:A"\t1',
#  '"49:100224285:chr1"\t1',
#  '"49:100224285:chr1:G"\t1',
#  '"49:100224286:chr1"\t1',
#  '"49:100224286:chr1:C"\t1',
#  '"49:100224287:chr1"\t1',
#  '"49:100224287:chr1:A"\t1',
#  '"49:100224288:chr1"\t1',
#  '"49:100224288:chr1:A"\t1',
#  '"49:100224289:chr1"\t1',
#  '"49:100224289:chr1:G"\t1',
#  '"49:100224290:chr1"\t1',
#  '"49:100224290:chr1:G"\t1',
#  '"49:100224291:chr1"\t1',
#  '"49:100224291:chr1:A"\t1',
#  '"49:100224292:chr1"\t1',
#  '"49:100224292:chr1:A"\t1',
#  '"49:100224293:chr1"\t1',
#  '"49:100224293:chr1:T"\t1',
#  '"49:100224294:chr1"\t1',
#  '"49:100224294:chr1:A"\t1',
#  '"49:100224295:chr1"\t1',
#  '"49:100224295:chr1:T"\t1',
#  '"49:100224296:chr1"\t1',
#  '"49:100224296:chr1:T"\t1',
#  '"49:100224297:chr1"\t1',
#  '"49:100224297:chr1:A"\t1',
#  '"49:100224298:chr1"\t1',
#  '"49:100224298:chr1:A"\t1',
#  '"49:100224299:chr1"\t1',
#  '"49:100224299:chr1:T"\t1',
#  '"49:100224300:chr1"\t1',
#  '"49:100224300:chr1:A"\t1',
#  '"49:100224301:chr1"\t1',
#  '"49:100224301:chr1:T"\t1',
#  '"49:100224302:chr1"\t1',
#  '"49:100224302:chr1:T"\t1',
#  '"49:100224303:chr1"\t1',
#  '"49:100224303:chr1:A"\t1',
#  '"49:100224304:chr1"\t1',
#  '"49:100224304:chr1:A"\t1',
#  '"49:100224305:chr1"\t1',
#  '"49:100224305:chr1:T"\t1',
#  '"49:100224306:chr1"\t1',
#  '"49:100224306:chr1:A"\t1',
#  '"49:100224307:chr1"\t1',
#  '"49:100224307:chr1:C"\t1',
#  '"49:100224308:chr1"\t1',
#  '"49:100224308:chr1:C"\t1',
#  '"49:100224309:chr1"\t1',
#  '"49:100224309:chr1:C"\t1',
#  '"49:100224310:chr1"\t1',
#  '"49:100224310:chr1:T"\t1',
#  '"49:100224311:chr1"\t1',
#  '"49:100224311:chr1:G"\t1',
#  '"49:100224312:chr1"\t1',
#  '"49:100224312:chr1:G"\t1',
#  '"49:100224313:chr1"\t1',
#  '"49:100224313:chr1:G"\t1',
#  '"49:100224314:chr1"\t1',
#  '"49:100224314:chr1:A"\t1',
#  '"49:100224315:chr1"\t1',
#  '"49:100224315:chr1:A"\t1',
#  '"49:100224316:chr1"\t1',
#  '"49:100224316:chr1:A"\t1',
#  '"49:100224317:chr1"\t1',
#  '"49:100224317:chr1:G"\t1',
#  '"49:100224318:chr1"\t1',
#  '"49:100224318:chr1:G"\t1',
#  '"49:100224319:chr1"\t1',
#  '"49:100224319:chr1:A"\t1',
#  '"49:100224320:chr1"\t1',
#  '"49:100224320:chr1:A"\t1',
#  '"49:100224321:chr1"\t1',
#  '"49:100224321:chr1:T"\t1',
#  '"49:100224322:chr1"\t1',
#  '"49:100224322:chr1:G"\t1',
#  '"49:100224323:chr1"\t1',
#  '"49:100224323:chr1:C"\t1',
#  '"49:100224324:chr1"\t1',
#  '"49:100224324:chr1:A"\t1',
#  '"49:100224325:chr1"\t1',
#  '"49:100224325:chr1:C"\t1',
#  '"49:100224326:chr1"\t1',
#  '"49:100224326:chr1:T"\t1',
#  '"49:100224327:chr1"\t1',
#  '"49:100224327:chr1:C"\t1',
#  '"49:100224328:chr1"\t1',
#  '"49:100224328:chr1:C"\t1',
#  '"49:100224329:chr1"\t1',
#  '"49:100224329:chr1:T"\t1',
#  '"49:100224330:chr1"\t1',
#  '"49:100224330:chr1:G"\t1',
#  '"49:100224331:chr1"\t1',
#  '"49:100224331:chr1:G"\t1',
#  '"49:10022:chr1"\t2',
#  '"49:10022:chr1:C"\t2',
#  '"49:10023:chr1"\t2',
#  '"49:10023:chr1:C"\t2',
#  '"49:10024:chr1"\t2',
#  '"49:10024:chr1:C"\t2',
#  '"49:10025:chr1"\t2',
#  '"49:10025:chr1:T"\t2',
#  '"49:10026:chr1"\t2',
#  '"49:10026:chr1:A"\t2',
#  '"49:10027:chr1"\t2',
#  '"49:10027:chr1:A"\t2',
#  '"49:10028:chr1"\t2',
#  '"49:10028:chr1:C"\t2',
#  '"49:10029:chr1"\t2',
#  '"49:10029:chr1:C"\t2',
#  '"49:10030:chr1"\t2',
#  '"49:10030:chr1:C"\t2',
#  '"49:10031:chr1"\t2',
#  '"49:10031:chr1:T"\t2',
#  '"49:10032:chr1"\t2',
#  '"49:10032:chr1:A"\t2',
#  '"49:10033:chr1"\t2',
#  '"49:10033:chr1:A"\t2',
#  '"49:10034:chr1"\t2',
#  '"49:10034:chr1:C"\t2',
#  '"49:10035:chr1"\t2',
#  '"49:10035:chr1:C"\t2',
#  '"49:10036:chr1"\t2',
#  '"49:10036:chr1:C"\t2',
#  '"49:10037:chr1"\t2',
#  '"49:10037:chr1:T"\t2',
#  '"49:10038:chr1"\t2',
#  '"49:10038:chr1:A"\t2',
#  '"49:10039:chr1"\t2',
#  '"49:10039:chr1:A"\t2',
#  '"49:10040:chr1"\t2',
#  '"49:10040:chr1:C"\t2',
#  '"49:10041:chr1"\t2',
#  '"49:10041:chr1:C"\t2',
#  '"49:10042:chr1"\t2',
#  '"49:10042:chr1:C"\t2',
#  '"49:10043:chr1"\t2',
#  '"49:10043:chr1:T"\t2',
#  '"49:10044:chr1"\t2',
#  '"49:10044:chr1:A"\t2',
#  '"49:10045:chr1"\t2',
#  '"49:10045:chr1:A"\t2',
#  '"49:10046:chr1"\t2',
#  '"49:10046:chr1:C"\t2',
#  '"49:10047:chr1"\t2',
#  '"49:10047:chr1:C"\t2',
#  '"49:10048:chr1"\t2',
#  '"49:10048:chr1:C"\t2',
#  '"49:10049:chr1"\t2',
#  '"49:10049:chr1:T"\t2',
#  '"49:10050:chr1"\t2',
#  '"49:10050:chr1:A"\t2',
#  '"49:10051:chr1"\t2',
#  '"49:10051:chr1:A"\t2',
#  '"49:10052:chr1"\t2',
#  '"49:10052:chr1:C"\t2',
#  '"49:10053:chr1"\t2',
#  '"49:10053:chr1:C"\t2',
#  '"49:10054:chr1"\t2',
#  '"49:10054:chr1:C"\t2',
#  '"49:10055:chr1"\t2',
#  '"49:10055:chr1:T"\t2',
#  '"49:10056:chr1"\t2',
#  '"49:10056:chr1:A"\t2',
#  '"49:10057:chr1"\t2',
#  '"49:10057:chr1:A"\t2',
#  '"49:10058:chr1"\t2',
#  '"49:10058:chr1:C"\t2',
#  '"49:10059:chr1"\t2',
#  '"49:10059:chr1:C"\t2',
#  '"49:10060:chr1"\t2',
#  '"49:10060:chr1:C"\t2',
#  '"49:10061:chr1"\t2',
#  '"49:10061:chr1:T"\t2',
#  '"49:10062:chr1"\t2',
#  '"49:10062:chr1:A"\t2',
#  '"49:10063:chr1"\t2',
#  '"49:10063:chr1:A"\t2',
#  '"49:10064:chr1"\t2',
#  '"49:10064:chr1:C"\t2',
#  '"49:10065:chr1"\t2',
#  '"49:10065:chr1:C"\t2',
#  '"49:100666562:chr1"\t1',
#  '"49:100666562:chr1:C"\t1',
#  '"49:100666563:chr1"\t1',
#  '"49:100666563:chr1:A"\t1',
#  '"49:100666564:chr1"\t1',
#  '"49:100666564:chr1:A"\t1',
#  '"49:100666565:chr1"\t1',
#  '"49:100666565:chr1:A"\t1',
#  '"49:100666566:chr1"\t1',
#  '"49:100666566:chr1:G"\t1',
#  '"49:100666567:chr1"\t1',
#  '"49:100666567:chr1:G"\t1',
#  '"49:100666568:chr1"\t1',
#  '"49:100666568:chr1:A"\t1',
#  '"49:100666569:chr1"\t1',
#  '"49:100666569:chr1:T"\t1',
#  '"49:100666570:chr1"\t1',
#  '"49:100666570:chr1:C"\t1',
#  '"49:100666571:chr1"\t1',
#  '"49:100666571:chr1:A"\t1',
#  '"49:100666572:chr1"\t1',
#  '"49:100666572:chr1:C"\t1',
#  '"49:100666573:chr1"\t1',
#  '"49:100666573:chr1:A"\t1',
#  '"49:100666574:chr1"\t1',
#  '"49:100666574:chr1:A"\t1',
#  '"49:100666575:chr1"\t1',
#  '"49:100666575:chr1:C"\t1',
#  '"49:100666576:chr1"\t1',
#  '"49:100666576:chr1:T"\t1',
#  '"49:100666577:chr1"\t1',
#  '"49:100666577:chr1:C"\t1',
#  '"49:100666578:chr1"\t1',
#  '"49:100666578:chr1:C"\t1',
#  '"49:100666579:chr1"\t1',
#  '"49:100666579:chr1:T"\t1',
#  '"49:100666580:chr1"\t1',
#  '"49:100666580:chr1:C"\t1',
#  '"49:100666581:chr1"\t1',
#  '"49:100666581:chr1:G"\t1',
#  '"49:100666582:chr1"\t1',
#  '"49:100666582:chr1:C"\t1',
#  '"49:100666583:chr1"\t1',
#  '"49:100666583:chr1:C"\t1',
#  '"49:100666584:chr1"\t1',
#  '"49:100666584:chr1:A"\t1',
#  '"49:100666585:chr1"\t1',
#  '"49:100666585:chr1:G"\t1',
#  '"49:100666586:chr1"\t1',
#  '"49:100666586:chr1:C"\t1',
#  '"49:100666587:chr1"\t1',
#  '"49:100666587:chr1:A"\t1',
#  '"49:100666588:chr1"\t1',
#  '"49:100666588:chr1:A"\t1',
#  '"49:100666589:chr1"\t1',
#  '"49:100666589:chr1:G"\t1',
#  '"49:100666590:chr1"\t1',
#  '"49:100666590:chr1:G"\t1',
#  '"49:100666591:chr1"\t1',
#  '"49:100666591:chr1:G"\t1',
#  '"49:100666592:chr1"\t1',
#  '"49:100666592:chr1:A"\t1',
#  '"49:100666593:chr1"\t1',
#  '"49:100666593:chr1:A"\t1',
#  '"49:100666594:chr1"\t1',
#  '"49:100666594:chr1:C"\t1',
#  '"49:100666595:chr1"\t1',
#  '"49:100666595:chr1:A"\t1',
#  '"49:100666596:chr1"\t1',
#  '"49:100666596:chr1:A"\t1',
#  '"49:100666597:chr1"\t1',
#  '"49:100666597:chr1:A"\t1',
#  '"49:100666598:chr1"\t1',
#  '"49:100666598:chr1:A"\t1',
#  '"49:100666599:chr1"\t1',
#  '"49:100666599:chr1:C"\t1',
#  '"49:100666600:chr1"\t1',
#  '"49:100666600:chr1:T"\t1',
#  '"49:100666601:chr1"\t1',
#  '"49:100666601:chr1:G"\t1',
#  '"49:100666602:chr1"\t1',
#  '"49:100666602:chr1:G"\t1',
#  '"49:100666603:chr1"\t1',
#  '"49:100666603:chr1:A"\t1',
#  '"49:100666604:chr1"\t1',
#  '"49:100666604:chr1:C"\t1',
#  '"49:100666605:chr1"\t1',
#  '"49:100666605:chr1:A"\t1',
#  '"49:100666606:chr1"\t1',
#  '"49:100666606:chr1:G"\t1',
#  '"49:100666607:chr1"\t1',
#  '"49:100666607:chr1:A"\t1',
#  '"49:100666608:chr1"\t1',
#  '"49:100666608:chr1:G"\t1',
#  '"49:100666609:chr1"\t1',
#  '"49:100666609:chr1:A"\t1',
#  '"49:100666610:chr1"\t1',
#  '"49:100666610:chr1:A"\t1',
#  '"49:100666611:chr1"\t1',
#  '"49:100666611:chr1:T"\t1',
#  '"49:100666612:chr1"\t1',
#  '"49:100666612:chr1:G"\t1',
#  '"49:100666613:chr1"\t1',
#  '"49:100666613:chr1:A"\t1',
#  '"49:100666614:chr1"\t1',
#  '"49:100666614:chr1:G"\t1',
#  '"49:100666615:chr1"\t1',
#  '"49:100666615:chr1:T"\t1',
#  '"49:100666616:chr1"\t1',
#  '"49:100666616:chr1:T"\t1',
#  '"49:100666617:chr1"\t1',
#  '"49:100666617:chr1:T"\t1',
#  '"49:100666618:chr1"\t1',
#  '"49:100666618:chr1:G"\t1',
#  '"49:100666619:chr1"\t1',
#  '"49:100666619:chr1:A"\t1',
#  '"49:100666620:chr1"\t1',
#  '"49:100666620:chr1:T"\t1',
#  '"49:100666621:chr1"\t1',
#  '"49:100666621:chr1:G"\t1',
#  '"49:100666622:chr1"\t1',
#  '"49:100666622:chr1:A"\t1',
#  '"49:100666623:chr1"\t1',
#  '"49:100666623:chr1:A"\t1',
#  '"49:100666624:chr1"\t1',
#  '"49:100666624:chr1:C"\t1',
#  '"49:100666625:chr1"\t1',
#  '"49:100666625:chr1:T"\t1',
#  '"49:100666626:chr1"\t1',
#  '"49:100666626:chr1:G"\t1',
#  '"49:100666627:chr1"\t1',
#  '"49:100666627:chr1:A"\t1',
#  '"49:100666628:chr1"\t1',
#  '"49:100666628:chr1:C"\t1',
#  '"49:100666629:chr1"\t1',
#  '"49:100666629:chr1:A"\t1',
#  '"49:100666630:chr1"\t1',
#  '"49:100666630:chr1:C"\t1',
#  '"49:100666631:chr1"\t1',
#  '"49:100666631:chr1:A"\t1',
#  '"49:100666632:chr1"\t1',
#  '"49:100666632:chr1:A"\t1',
#  '"49:100666633:chr1"\t1',
#  '"49:100666633:chr1:G"\t1',
#  '"49:100666634:chr1"\t1',
#  '"49:100666634:chr1:T"\t1',
#  '"49:100666635:chr1"\t1',
#  '"49:100666635:chr1:A"\t1',
#  '"49:100666636:chr1"\t1',
#  '"49:100666636:chr1:G"\t1',
#  '"49:10066:chr1"\t2',
#  '"49:10066:chr1:C"\t2',
#  '"49:10067:chr1"\t2',
#  '"49:10067:chr1:T"\t2',
#  '"49:10068:chr1"\t2',
#  '"49:10068:chr1:A"\t2',
#  '"49:10069:chr1"\t2',
#  '"49:10069:chr1:A"\t2',
#  '"49:10070:chr1"\t2',
#  '"49:10070:chr1:C"\t2',
#  '"49:10071:chr1"\t2',
#  '"49:10071:chr1:C"\t2',
#  '"49:10072:chr1"\t2',
#  '"49:10072:chr1:C"\t2',
#  '"49:101355535:chr1"\t1',
#  '"49:101355535:chr1:C"\t1',
#  '"49:101355536:chr1"\t1',
#  '"49:101355536:chr1:C"\t1',
#  '"49:101355537:chr1"\t1',
#  '"49:101355537:chr1:A"\t1',
#  '"49:101355538:chr1"\t1',
#  '"49:101355538:chr1:T"\t1',
#  '"49:101355539:chr1"\t1',
#  '"49:101355539:chr1:G"\t1',
#  '"49:101355540:chr1"\t1',
#  '"49:101355540:chr1:A"\t1',
#  '"49:101355541:chr1"\t1',
#  '"49:101355541:chr1:G"\t1',
#  '"49:101355542:chr1"\t1',
#  '"49:101355542:chr1:G"\t1',
#  '"49:101355543:chr1"\t1',
#  '"49:101355543:chr1:G"\t1',
#  '"49:101355544:chr1"\t1',
#  '"49:101355544:chr1:C"\t1',
#  '"49:101355545:chr1"\t1',
#  '"49:101355545:chr1:T"\t1',
#  '"49:101355546:chr1"\t1',
#  '"49:101355546:chr1:C"\t1',
#  '"49:101355547:chr1"\t1',
#  '"49:101355547:chr1:C"\t1',
#  '"49:101355548:chr1"\t1',
#  '"49:101355548:chr1:A"\t1',
#  '"49:101355549:chr1"\t1',
#  '"49:101355549:chr1:C"\t1',
#  '"49:101355550:chr1"\t1',
#  '"49:101355550:chr1:C"\t1',
#  '"49:101355551:chr1"\t1',
#  '"49:101355551:chr1:C"\t1',
#  '"49:101355552:chr1"\t1',
#  '"49:101355552:chr1:C"\t1',
#  '"49:101355553:chr1"\t1',
#  '"49:101355553:chr1:T"\t1',
#  '"49:101355554:chr1"\t1',
#  '"49:101355554:chr1:G"\t1',
#  '"49:101355555:chr1"\t1',
#  '"49:101355555:chr1:C"\t1',
#  '"49:101355556:chr1"\t1',
#  '"49:101355556:chr1:A"\t1',
#  '"49:101355557:chr1"\t1',
#  '"49:101355557:chr1:G"\t1',
#  '"49:101355558:chr1"\t1',
#  '"49:101355558:chr1:C"\t1',
#  '"49:101355559:chr1"\t1',
#  '"49:101355559:chr1:A"\t1',
#  '"49:101355560:chr1"\t1',
#  '"49:101355560:chr1:A"\t1',
#  '"49:101355561:chr1"\t1',
#  '"49:101355561:chr1:A"\t1',
#  '"49:101355562:chr1"\t1',
#  '"49:101355562:chr1:C"\t1',
#  '"49:101355563:chr1"\t1',
#  '"49:101355563:chr1:T"\t1',
#  '"49:101355564:chr1"\t1',
#  '"49:101355564:chr1:T"\t1',
#  '"49:101355565:chr1"\t1',
#  '"49:101355565:chr1:C"\t1',
#  '"49:101355566:chr1"\t1',
#  '"49:101355566:chr1:T"\t1',
#  '"49:101355567:chr1"\t1',
#  '"49:101355567:chr1:G"\t1',
#  '"49:101355568:chr1"\t1',
#  '"49:101355568:chr1:C"\t1',
#  '"49:101355569:chr1"\t1',
#  '"49:101355569:chr1:C"\t1',
#  '"49:101355570:chr1"\t1',
#  '"49:101355570:chr1:T"\t1',
#  '"49:101355571:chr1"\t1',
#  '"49:101355571:chr1:G"\t1',
#  '"49:101355572:chr1"\t1',
#  '"49:101355572:chr1:G"\t1',
#  '"49:101355573:chr1"\t1',
#  '"49:101355573:chr1:A"\t1',
#  '"49:101355574:chr1"\t1',
#  '"49:101355574:chr1:C"\t1',
#  '"49:101355575:chr1"\t1',
#  '"49:101355575:chr1:A"\t1',
#  '"49:101355576:chr1"\t1',
#  '"49:101355576:chr1:T"\t1',
#  '"49:101355577:chr1"\t1',
#  '"49:101355577:chr1:C"\t1',
#  '"49:101355578:chr1"\t1',
#  '"49:101355578:chr1:C"\t1',
#  '"49:101355579:chr1"\t1',
#  '"49:101355579:chr1:A"\t1',
#  '"49:101355580:chr1"\t1',
#  '"49:101355580:chr1:G"\t1',
#  '"49:101355581:chr1"\t1',
#  '"49:101355581:chr1:G"\t1',
#  '"49:101355582:chr1"\t1',
#  '"49:101355582:chr1:C"\t1',
#  '"49:101355583:chr1"\t1',
#  '"49:101355583:chr1:A"\t1',
#  '"49:101355584:chr1"\t1',
#  '"49:101355584:chr1:T"\t1',
#  '"49:101355585:chr1"\t1',
#  '"49:101355585:chr1:T"\t1',
#  '"49:101355586:chr1"\t1',
#  '"49:101355586:chr1:T"\t1',
#  '"49:101355587:chr1"\t1',
#  '"49:101355587:chr1:C"\t1',
#  '"49:101355588:chr1"\t1',
#  '"49:101355588:chr1:C"\t1',
#  '"49:101355589:chr1"\t1',
#  '"49:101355589:chr1:A"\t1',
#  '"49:101355590:chr1"\t1',
#  '"49:101355590:chr1:T"\t1',
#  '"49:101355591:chr1"\t1',
#  '"49:101355591:chr1:A"\t1',
#  '"49:101355592:chr1"\t1',
#  '"49:101355592:chr1:C"\t1',
#  '"49:101355593:chr1"\t1',
#  '"49:101355593:chr1:A"\t1',
#  '"49:101355594:chr1"\t1',
#  '"49:101355594:chr1:T"\t1',
#  '"49:101355595:chr1"\t1',
#  '"49:101355595:chr1:C"\t1',
#  '"49:101355596:chr1"\t1',
#  '"49:101355596:chr1:C"\t1',
#  '"49:101355597:chr1"\t1',
#  '"49:101355597:chr1:T"\t1',
#  '"49:101355598:chr1"\t1',
#  '"49:101355598:chr1:C"\t1',
#  '"49:101355599:chr1"\t1',
#  '"49:101355599:chr1:T"\t1',
#  '"49:101355600:chr1"\t1',
#  '"49:101355600:chr1:G"\t1',
#  '"49:101355601:chr1"\t1',
#  '"49:101355601:chr1:A"\t1',
#  '"49:101355602:chr1"\t1',
#  '"49:101355602:chr1:A"\t1',
#  '"49:101355603:chr1"\t1',
#  '"49:101355603:chr1:A"\t1',
#  '"49:101355604:chr1"\t1',
#  '"49:101355604:chr1:T"\t1',
#  '"49:101355605:chr1"\t1',
#  '"49:101355605:chr1:G"\t1',
#  '"49:101355606:chr1"\t1',
#  '"49:101355606:chr1:T"\t1',
#  '"49:101355607:chr1"\t1',
#  '"49:101355607:chr1:A"\t1',
#  '"49:101355608:chr1"\t2',
#  '"49:101355608:chr1:G"\t2',
#  '"49:101355609:chr1"\t2',
#  '"49:101355609:chr1:C"\t2',
#  '"49:101355610:chr1"\t1',
#  '"49:101355610:chr1:C"\t1',
#  '"49:101355611:chr1"\t1',
#  '"49:101355611:chr1:A"\t1',
#  '"49:101355612:chr1"\t1',
#  '"49:101355612:chr1:T"\t1',
#  '"49:101355613:chr1"\t1',
#  '"49:101355613:chr1:G"\t1',
#  '"49:101355614:chr1"\t1',
#  '"49:101355614:chr1:A"\t1',
#  '"49:101355615:chr1"\t1',
#  '"49:101355615:chr1:G"\t1',
#  '"49:101355616:chr1"\t1',
#  '"49:101355616:chr1:G"\t1',
#  '"49:101355617:chr1"\t1',
#  '"49:101355617:chr1:G"\t1',
#  '"49:101355618:chr1"\t1',
#  '"49:101355618:chr1:C"\t1',
#  '"49:101355619:chr1"\t1',
#  '"49:101355619:chr1:T"\t1',
#  '"49:101355620:chr1"\t1',
#  '"49:101355620:chr1:C"\t1',
#  '"49:101355621:chr1"\t1',
#  '"49:101355621:chr1:C"\t1',
#  '"49:101355622:chr1"\t1',
#  '"49:101355622:chr1:A"\t1',
#  '"49:101355623:chr1"\t1',
#  '"49:101355623:chr1:C"\t1',
#  '"49:101355624:chr1"\t1',
#  '"49:101355624:chr1:C"\t1',
#  '"49:101355625:chr1"\t1',
#  '"49:101355625:chr1:C"\t1',
#  '"49:101355626:chr1"\t1',
#  '"49:101355626:chr1:C"\t1',
#  '"49:101355627:chr1"\t1',
#  '"49:101355627:chr1:T"\t1',
#  '"49:101355628:chr1"\t1',
#  '"49:101355628:chr1:G"\t1',
#  '"49:101355629:chr1"\t1',
#  '"49:101355629:chr1:C"\t1',
#  '"49:101355630:chr1"\t1',
#  '"49:101355630:chr1:A"\t1',
#  '"49:101355631:chr1"\t1',
#  '"49:101355631:chr1:G"\t1',
#  '"49:101355632:chr1"\t1',
#  '"49:101355632:chr1:C"\t1',
#  '"49:101355633:chr1"\t1',
#  '"49:101355633:chr1:A"\t1',
#  '"49:101355634:chr1"\t1',
#  '"49:101355634:chr1:A"\t1',
#  '"49:101355635:chr1"\t1',
#  '"49:101355635:chr1:A"\t1',
#  '"49:101355636:chr1"\t1',
#  '"49:101355636:chr1:C"\t1',
#  '"49:101355637:chr1"\t1',
#  '"49:101355637:chr1:T"\t1',
#  '"49:101355638:chr1"\t1',
#  '"49:101355638:chr1:T"\t1',
#  '"49:101355639:chr1"\t1',
#  '"49:101355639:chr1:C"\t1',
#  '"49:101355640:chr1"\t1',
#  '"49:101355640:chr1:T"\t1',
#  '"49:101355641:chr1"\t1',
#  '"49:101355641:chr1:G"\t1',
#  '"49:101355642:chr1"\t1',
#  '"49:101355642:chr1:C"\t1',
#  '"49:101355643:chr1"\t1',
#  '"49:101355643:chr1:C"\t1',
#  '"49:101355644:chr1"\t1',
#  '"49:101355644:chr1:T"\t1',
#  '"49:101355645:chr1"\t1',
#  '"49:101355645:chr1:G"\t1',
#  '"49:101355646:chr1"\t1',
#  '"49:101355646:chr1:G"\t1',
#  '"49:101355647:chr1"\t1',
#  '"49:101355647:chr1:A"\t1',
#  '"49:101355648:chr1"\t1',
#  '"49:101355648:chr1:C"\t1',
#  '"49:101355649:chr1"\t1',
#  '"49:101355649:chr1:A"\t1',
#  '"49:101355650:chr1"\t1',
#  '"49:101355650:chr1:T"\t1',
#  '"49:101355651:chr1"\t1',
#  '"49:101355651:chr1:C"\t1',
#  '"49:101355652:chr1"\t1',
#  '"49:101355652:chr1:C"\t1',
#  '"49:101355653:chr1"\t1',
#  '"49:101355653:chr1:A"\t1',
#  '"49:101355655:chr1"\t1',
#  '"49:101355655:chr1:G"\t1',
#  '"49:101355656:chr1"\t1',
#  '"49:101355656:chr1:C"\t1',
#  '"49:101355657:chr1"\t1',
#  '"49:101355657:chr1:A"\t1',
#  '"49:101355658:chr1"\t1',
#  '"49:101355658:chr1:T"\t1',
#  '"49:101355659:chr1"\t1',
#  '"49:101355659:chr1:T"\t1',
#  '"49:101355660:chr1"\t1',
#  '"49:101355660:chr1:T"\t1',
#  '"49:101355661:chr1"\t1',
#  '"49:101355661:chr1:C"\t1',
#  '"49:101355662:chr1"\t1',
#  '"49:101355662:chr1:C"\t1',
#  '"49:101355663:chr1"\t1',
#  '"49:101355663:chr1:A"\t1',
#  '"49:101355665:chr1"\t1',
#  '"49:101355665:chr1:A"\t1',
#  '"49:101355666:chr1"\t1',
#  '"49:101355666:chr1:C"\t1',
#  '"49:101355667:chr1"\t1',
#  '"49:101355667:chr1:A"\t1',
#  '"49:101355668:chr1"\t1',
#  '"49:101355668:chr1:T"\t1',
#  '"49:101355669:chr1"\t1',
#  '"49:101355669:chr1:C"\t1',
#  '"49:101355670:chr1"\t1',
#  '"49:101355670:chr1:C"\t1',
#  '"49:101355671:chr1"\t1',
#  '"49:101355671:chr1:T"\t1',
#  '"49:101355672:chr1"\t1',
#  '"49:101355672:chr1:C"\t1',
#  '"49:101355673:chr1"\t1',
#  '"49:101355673:chr1:T"\t1',
#  '"49:101355674:chr1"\t1',
#  '"49:101355674:chr1:G"\t1',
#  '"49:101355675:chr1"\t1',
#  '"49:101355675:chr1:A"\t1',
#  '"49:101355676:chr1"\t1',
#  '"49:101355676:chr1:A"\t1',
#  '"49:101355677:chr1"\t1',
#  '"49:101355677:chr1:A"\t1',
#  '"49:101355678:chr1"\t1',
#  '"49:101355678:chr1:T"\t1',
#  '"49:101355679:chr1"\t1',
#  '"49:101355679:chr1:G"\t1',
#  '"49:101355680:chr1"\t1',
#  '"49:101355680:chr1:T"\t1',
#  '"49:101355681:chr1"\t1',
#  '"49:101355681:chr1:A"\t1',
#  '"49:101355682:chr1"\t1',
#  '"49:101355682:chr1:G"\t1',
#  '"49:101413224:chr1"\t1',
#  '"49:101413224:chr1:C"\t1',
#  '"49:101413225:chr1"\t1',
#  '"49:101413225:chr1:A"\t1',
#  '"49:101413226:chr1"\t1',
#  '"49:101413226:chr1:T"\t1',
#  '"49:101413227:chr1"\t1',
#  '"49:101413227:chr1:A"\t1',
#  '"49:101413228:chr1"\t1',
#  '"49:101413228:chr1:T"\t1',
#  '"49:101413229:chr1"\t1',
#  '"49:101413229:chr1:A"\t1',
#  '"49:101413230:chr1"\t1',
#  '"49:101413230:chr1:T"\t1',
#  '"49:101413231:chr1"\t1',
#  '"49:101413231:chr1:A"\t1',
#  '"49:101413232:chr1"\t1',
#  '"49:101413232:chr1:T"\t1',
#  '"49:101413233:chr1"\t1',
#  '"49:101413233:chr1:T"\t1',
#  '"49:101413234:chr1"\t1',
#  '"49:101413234:chr1:T"\t1',
#  '"49:101413235:chr1"\t1',
#  '"49:101413235:chr1:A"\t1',
#  '"49:101413236:chr1"\t1',
#  '"49:101413236:chr1:G"\t1',
#  '"49:101413237:chr1"\t1',
#  '"49:101413237:chr1:G"\t1',
#  '"49:101413238:chr1"\t1',
#  '"49:101413238:chr1:A"\t1',
#  '"49:101413239:chr1"\t1',
#  '"49:101413239:chr1:T"\t1',
#  '"49:101413240:chr1"\t1',
#  '"49:101413240:chr1:A"\t1',
#  '"49:101413241:chr1"\t1',
#  '"49:101413241:chr1:G"\t1',
#  '"49:101413242:chr1"\t1',
#  '"49:101413242:chr1:T"\t1',
#  '"49:101413243:chr1"\t1',
#  '"49:101413243:chr1:T"\t1',
#  '"49:101413244:chr1"\t1',
#  '"49:101413244:chr1:A"\t1',
#  '"49:101413245:chr1"\t1',
#  '"49:101413245:chr1:G"\t1',
#  '"49:101413246:chr1"\t1',
#  '"49:101413246:chr1:C"\t1',
#  '"49:101413247:chr1"\t1',
#  '"49:101413247:chr1:T"\t1',
#  '"49:101413248:chr1"\t1',
#  '"49:101413248:chr1:C"\t1',
#  '"49:101413249:chr1"\t1',
#  '"49:101413249:chr1:T"\t1',
#  '"49:101413250:chr1"\t1',
#  '"49:101413250:chr1:T"\t1',
#  '"49:101413251:chr1"\t1',
#  '"49:101413251:chr1:C"\t1',
#  '"49:101413252:chr1"\t1',
#  '"49:101413252:chr1:T"\t1',
#  '"49:101413253:chr1"\t1',
#  '"49:101413253:chr1:T"\t1',
#  '"49:101413254:chr1"\t1',
#  '"49:101413254:chr1:G"\t1',
#  '"49:101413255:chr1"\t1',
#  '"49:101413255:chr1:T"\t1',
#  '"49:101413256:chr1"\t1',
#  '"49:101413256:chr1:T"\t1',
#  '"49:101413257:chr1"\t1',
#  '"49:101413257:chr1:G"\t1',
#  '"49:101413258:chr1"\t1',
#  '"49:101413258:chr1:A"\t1',
#  '"49:101413259:chr1"\t1',
#  '"49:101413259:chr1:A"\t1',
#  '"49:101413260:chr1"\t1',
#  '"49:101413260:chr1:T"\t1',
#  '"49:101413261:chr1"\t1',
#  '"49:101413261:chr1:T"\t1',
#  '"49:101413262:chr1"\t1',
#  '"49:101413262:chr1:G"\t1',
#  '"49:101413263:chr1"\t1',
#  '"49:101413263:chr1:A"\t1',
#  '"49:101413264:chr1"\t1',
#  '"49:101413264:chr1:T"\t1',
#  '"49:101413265:chr1"\t1',
#  '"49:101413265:chr1:C"\t1',
#  '"49:101413266:chr1"\t1',
#  '"49:101413266:chr1:C"\t1',
#  '"49:101413267:chr1"\t1',
#  '"49:101413267:chr1:C"\t1',
#  '"49:101413268:chr1"\t1',
#  '"49:101413268:chr1:T"\t1',
#  '"49:101413269:chr1"\t1',
#  '"49:101413269:chr1:T"\t1',
#  '"49:101413270:chr1"\t1',
#  '"49:101413270:chr1:T"\t1',
#  '"49:101413271:chr1"\t1',
#  '"49:101413271:chr1:A"\t1',
#  '"49:101413272:chr1"\t1',
#  '"49:101413272:chr1:C"\t1',
#  '"49:101413273:chr1"\t1',
#  '"49:101413273:chr1:C"\t1',
#  '"49:101413274:chr1"\t1',
#  '"49:101413274:chr1:A"\t1',
#  '"49:101413275:chr1"\t1',
#  '"49:101413275:chr1:T"\t1',
#  '"49:101413276:chr1"\t1',
#  '"49:101413276:chr1:T"\t1',
#  '"49:101413277:chr1"\t1',
#  '"49:101413277:chr1:A"\t1',
#  '"49:101413278:chr1"\t1',
#  '"49:101413278:chr1:T"\t1',
#  '"49:101413279:chr1"\t1',
#  '"49:101413279:chr1:G"\t1',
#  '"49:101413280:chr1"\t1',
#  '"49:101413280:chr1:T"\t1',
#  '"49:101413281:chr1"\t1',
#  '"49:101413281:chr1:A"\t1',
#  '"49:101413282:chr1"\t1',
#  '"49:101413282:chr1:A"\t1',
#  '"49:101413283:chr1"\t1',
#  '"49:101413283:chr1:T"\t1',
#  '"49:101413284:chr1"\t1',
#  '"49:101413284:chr1:G"\t1',
#  '"49:101413285:chr1"\t1',
#  '"49:101413285:chr1:G"\t1',
#  '"49:101413286:chr1"\t1',
#  '"49:101413286:chr1:C"\t1',
#  '"49:101413287:chr1"\t1',
#  '"49:101413287:chr1:C"\t1',
#  '"49:101413288:chr1"\t1',
#  '"49:101413288:chr1:T"\t1',
#  '"49:101413289:chr1"\t1',
#  '"49:101413289:chr1:T"\t1',
#  '"49:101413290:chr1"\t1',
#  '"49:101413290:chr1:C"\t1',
#  '"49:101413291:chr1"\t1',
#  '"49:101413291:chr1:T"\t1',
#  '"49:101413292:chr1"\t1',
#  '"49:101413292:chr1:T"\t1',
#  '"49:101413293:chr1"\t1',
#  '"49:101413293:chr1:C"\t1',
#  '"49:101413294:chr1"\t1',
#  '"49:101413294:chr1:T"\t1',
#  '"49:101413295:chr1"\t1',
#  '"49:101413295:chr1:G"\t1',
#  '"49:101413296:chr1"\t1',
#  '"49:101413296:chr1:T"\t1',
#  '"49:101413297:chr1"\t1',
#  '"49:101413297:chr1:C"\t1',
#  '"49:101413298:chr1"\t1',
#  '"49:101413298:chr1:T"\t1',
#  '"49:103735533:chr1"\t1',
#  '"49:103735533:chr1:A"\t1',
#  '"49:103735534:chr1"\t1',
#  '"49:103735534:chr1:C"\t1',
#  '"49:103735535:chr1"\t1',
#  '"49:103735535:chr1:T"\t1',
#  '"49:103735536:chr1"\t1',
#  '"49:103735536:chr1:T"\t1',
#  '"49:103735537:chr1"\t1',
#  '"49:103735537:chr1:A"\t1',
#  '"49:103735538:chr1"\t1',
#  '"49:103735538:chr1:T"\t1',
#  '"49:103735539:chr1"\t1',
#  '"49:103735539:chr1:T"\t1',
#  '"49:103735540:chr1"\t1',
#  '"49:103735540:chr1:G"\t1',
#  '"49:103735541:chr1"\t1',
#  '"49:103735541:chr1:G"\t1',
#  '"49:103735542:chr1"\t1',
#  '"49:103735542:chr1:T"\t1',
#  '"49:103735543:chr1"\t1',
#  '"49:103735543:chr1:G"\t1',
#  '"49:103735544:chr1"\t1',
#  '"49:103735544:chr1:A"\t1',
#  '"49:103735545:chr1"\t1',
#  '"49:103735545:chr1:G"\t1',
#  '"49:103735546:chr1"\t1',
#  '"49:103735546:chr1:A"\t1',
#  '"49:103735547:chr1"\t1',
#  '"49:103735547:chr1:C"\t1',
#  '"49:103735548:chr1"\t1',
#  '"49:103735548:chr1:A"\t1',
#  '"49:103735549:chr1"\t1',
#  '"49:103735549:chr1:T"\t1',
#  '"49:103735550:chr1"\t1',
#  '"49:103735550:chr1:T"\t1',
#  '"49:103735551:chr1"\t1',
#  '"49:103735551:chr1:T"\t1',
#  '"49:103735552:chr1"\t1',
#  '"49:103735552:chr1:G"\t1',
#  '"49:103735553:chr1"\t1',
#  '"49:103735553:chr1:C"\t1',
#  '"49:103735554:chr1"\t1',
#  '"49:103735554:chr1:A"\t1',
#  '"49:103735555:chr1"\t1',
#  '"49:103735555:chr1:T"\t1',
#  '"49:103735556:chr1"\t1',
#  '"49:103735556:chr1:A"\t1',
#  '"49:103735557:chr1"\t1',
#  '"49:103735557:chr1:C"\t1',
#  '"49:103735558:chr1"\t1',
#  '"49:103735558:chr1:C"\t1',
#  '"49:103735559:chr1"\t1',
#  '"49:103735559:chr1:A"\t1',
#  '"49:103735560:chr1"\t1',
#  '"49:103735560:chr1:G"\t1',
#  '"49:103735561:chr1"\t1',
#  '"49:103735561:chr1:A"\t1',
#  '"49:103735562:chr1"\t1',
#  '"49:103735562:chr1:G"\t1',
#  '"49:103735563:chr1"\t1',
#  '"49:103735563:chr1:G"\t1',
#  '"49:103735564:chr1"\t1',
#  '"49:103735564:chr1:A"\t1',
#  '"49:103735565:chr1"\t1',
#  '"49:103735565:chr1:T"\t1',
#  '"49:103735566:chr1"\t1',
#  '"49:103735566:chr1:G"\t1',
#  '"49:103735567:chr1"\t1',
#  '"49:103735567:chr1:G"\t1',
#  '"49:103735568:chr1"\t1',
#  '"49:103735568:chr1:G"\t1',
#  '"49:103735569:chr1"\t1',
#  '"49:103735569:chr1:A"\t1',
#  '"49:103735570:chr1"\t1',
#  '"49:103735570:chr1:A"\t1',
#  '"49:103735571:chr1"\t1',
#  '"49:103735571:chr1:A"\t1',
#  '"49:103735572:chr1"\t1',
#  '"49:103735572:chr1:T"\t1',
#  '"49:103735573:chr1"\t1',
#  '"49:103735573:chr1:A"\t1',
#  '"49:103735574:chr1"\t1',
#  '"49:103735574:chr1:A"\t1',
#  '"49:103735575:chr1"\t1',
#  '"49:103735575:chr1:A"\t1',
#  '"49:103735576:chr1"\t1',
#  '"49:103735576:chr1:T"\t1',
#  '"49:103735577:chr1"\t1',
#  '"49:103735577:chr1:C"\t1',
#  '"49:103735578:chr1"\t1',
#  '"49:103735578:chr1:T"\t1',
#  '"49:103735579:chr1"\t1',
#  '"49:103735579:chr1:G"\t1',
#  '"49:103735580:chr1"\t1',
#  '"49:103735580:chr1:A"\t1',
#  '"49:103735581:chr1"\t1',
#  '"49:103735581:chr1:C"\t1',
#  '"49:103735582:chr1"\t1',
#  ...]

# %% [markdown]
# ## This is not going to work

# %%
! python $myfile -r hadoop $myshortinput 1> log.out 2> log.err

# %%
cat log.err
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# creating tmp directory /tmp/job.jovyan.20151214.163021.842422
# writing wrapper script to /tmp/job.jovyan.20151214.163021.842422/setup-wrapper.sh
# Looking for hadoop binary in /usr/local/hadoop/bin
# Using Hadoop version 2.6.0
# STDERR: mkdir: Permission denied: user=jovyan, access=WRITE, inode="/user":root:supergroup:drwxr-xr-x
# Traceback (most recent call last):
#   File "/opt/mrjob/mrjob/fs/hadoop.py", line 293, in mkdir
#     self.invoke_hadoop(args, ok_stderr=[_HADOOP_FILE_EXISTS_RE])
#   File "/opt/mrjob/mrjob/fs/hadoop.py", line 180, in invoke_hadoop
#     raise CalledProcessError(proc.returncode, args)
# subprocess.CalledProcessError: Command '['/usr/local/hadoop/bin/hadoop', 'fs', '-mkdir', '-p', 'hdfs:///user/jovyan/tmp/mrjob/job.jovyan.20151214.163021.842422/files/']' returned non-zero exit status 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "./tmp/job.py", line 33, in <module>
#     MRcoverage().run()
#   File "/opt/mrjob/mrjob/job.py", line 433, in run
#     mr_job.execute()
#   File "/opt/mrjob/mrjob/job.py", line 451, in execute
#     super(MRJob, self).execute()
#   File "/opt/mrjob/mrjob/launch.py", line 160, in execute
#     self.run_job()
#   File "/opt/mrjob/mrjob/launch.py", line 225, in run_job
#     runner.run()
#   File "/opt/mrjob/mrjob/runner.py", line 468, in run
#     self._run()
#   File "/opt/mrjob/mrjob/hadoop.py", line 274, in _run
#     self._upload_local_files_to_hdfs()
#   File "/opt/mrjob/mrjob/hadoop.py", line 301, in _upload_local_files_to_hdfs
#     self.fs.mkdir(self._upload_mgr.prefix)
#   File "/opt/mrjob/mrjob/fs/composite.py", line 75, in mkdir
#     return self._do_action('mkdir', path)
#   File "/opt/mrjob/mrjob/fs/composite.py", line 62, in _do_action
#     raise first_exception
#   File "/opt/mrjob/mrjob/fs/composite.py", line 54, in _do_action
#     return getattr(fs, action)(path, *args, **kwargs)
#   File "/opt/mrjob/mrjob/fs/hadoop.py", line 295, in mkdir
#     raise IOError("Could not mkdir %s" % path)
# OSError: Could not mkdir hdfs:///user/jovyan/tmp/mrjob/job.jovyan.20151214.163021.842422/files/

# %% [markdown]
# Your modules could be compressed and sent to HADOOP or EMR
#
# http://mrjob.readthedocs.org/en/latest/guides/setup-cookbook.html#putting-your-source-tree-in-pythonpath

# %%
cat $ngs_module $myfile > tmp/hadoop.py

# %%
! python tmp/hadoop.py -r hadoop $myshortinput
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# creating tmp directory /tmp/hadoop.jovyan.20151214.164022.701186
# writing wrapper script to /tmp/hadoop.jovyan.20151214.164022.701186/setup-wrapper.sh
# Looking for hadoop binary in /usr/local/hadoop/bin
# Using Hadoop version 2.6.0
# Copying local files into hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/files/
# Looking for Hadoop streaming jar in /usr/local/hadoop
# Found Hadoop streaming jar: /usr/local/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.6.0.jar
# HADOOP: packageJobJar: [/tmp/hadoop-unjar5440388343696524568/] [] /tmp/streamjob9001070335311574816.jar tmpDir=null
# HADOOP: Connecting to ResourceManager at /0.0.0.0:8032
# HADOOP: Connecting to ResourceManager at /0.0.0.0:8032
# HADOOP: Total input paths to process : 1
# HADOOP: number of splits:2
# HADOOP: Submitting tokens for job: job_1450107962907_0002
# HADOOP: Submitted application application_1450107962907_0002
# HADOOP: The url to track the job: http://d943ffbb3f6c:8088/proxy/application_1450107962907_0002/
# HADOOP: Running job: job_1450107962907_0002
# HADOOP: Job job_1450107962907_0002 running in uber mode : false
# HADOOP:  map 0% reduce 0%
# HADOOP:  map 50% reduce 0%
# HADOOP: Task Id : attempt_1450107962907_0002_m_000000_0, Status : FAILED
# HADOOP: Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 127
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# HADOOP: 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:450)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:163)
# HADOOP: 	at java.security.AccessController.doPrivileged(Native Method)
# HADOOP: 	at javax.security.auth.Subject.doAs(Subject.java:415)
# HADOOP: 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1628)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
# HADOOP:
# HADOOP: Container killed by the ApplicationMaster.
# HADOOP: Container killed on request. Exit code is 143
# HADOOP: Container exited with a non-zero exit code 143
# HADOOP:
# HADOOP: Task Id : attempt_1450107962907_0002_m_000001_0, Status : FAILED
# HADOOP: Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 127
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# HADOOP: 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:450)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:163)
# HADOOP: 	at java.security.AccessController.doPrivileged(Native Method)
# HADOOP: 	at javax.security.auth.Subject.doAs(Subject.java:415)
# HADOOP: 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1628)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
# HADOOP:
# HADOOP:  map 0% reduce 0%
# HADOOP: Task Id : attempt_1450107962907_0002_m_000000_1, Status : FAILED
# HADOOP: Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 127
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# HADOOP: 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:450)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:163)
# HADOOP: 	at java.security.AccessController.doPrivileged(Native Method)
# HADOOP: 	at javax.security.auth.Subject.doAs(Subject.java:415)
# HADOOP: 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1628)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
# HADOOP:
# HADOOP: Task Id : attempt_1450107962907_0002_m_000001_1, Status : FAILED
# HADOOP: Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 127
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# HADOOP: 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:450)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:163)
# HADOOP: 	at java.security.AccessController.doPrivileged(Native Method)
# HADOOP: 	at javax.security.auth.Subject.doAs(Subject.java:415)
# HADOOP: 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1628)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
# HADOOP:
# HADOOP: Task Id : attempt_1450107962907_0002_m_000000_2, Status : FAILED
# HADOOP: Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 127
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# HADOOP: 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:450)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:163)
# HADOOP: 	at java.security.AccessController.doPrivileged(Native Method)
# HADOOP: 	at javax.security.auth.Subject.doAs(Subject.java:415)
# HADOOP: 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1628)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
# HADOOP:
# HADOOP: Task Id : attempt_1450107962907_0002_m_000001_2, Status : FAILED
# HADOOP: Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 127
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# HADOOP: 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# HADOOP: 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:450)
# HADOOP: 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:163)
# HADOOP: 	at java.security.AccessController.doPrivileged(Native Method)
# HADOOP: 	at javax.security.auth.Subject.doAs(Subject.java:415)
# HADOOP: 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1628)
# HADOOP: 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
# HADOOP:
# HADOOP:  map 100% reduce 100%
# HADOOP: Job job_1450107962907_0002 failed with state FAILED due to: Task failed task_1450107962907_0002_m_000000
# HADOOP: Job failed as tasks failed. failedMaps:1 failedReduces:0
# HADOOP:
# Parsing counters from hadoop output
# HADOOP: Job not successful!
# HADOOP: Streaming Command Failed!
# Counters from step 1:
# 	Job Counters
# 		Data-local map tasks=2
# 		Failed map tasks=7
# 		Killed map tasks=1
# 		Launched map tasks=8
# 		Other local map tasks=6
# 		Total megabyte-seconds taken by all map tasks=32112640
# 		Total time spent by all map tasks (ms)=31360
# 		Total time spent by all maps in occupied slots (ms)=31360
# 		Total time spent by all reduces in occupied slots (ms)=0
# 		Total vcore-seconds taken by all map tasks=31360
# 	Map-Reduce Framework
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# Job failed with return code 256: ['/usr/local/hadoop/bin/hadoop', 'jar', '/usr/local/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.6.0.jar', '-files', 'hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/files/setup-wrapper.sh#setup-wrapper.sh,hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/files/hadoop.py#hadoop.py', '-archives', 'hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/files/mrjob.tar.gz#mrjob.tar.gz', '-input', 'hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/files/ngs.sam.short', '-output', 'hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/output', '-mapper', 'sh -ex setup-wrapper.sh python3 hadoop.py --step-num=0 --mapper', '-reducer', 'sh -ex setup-wrapper.sh python3 hadoop.py --step-num=0 --reducer']
# Scanning logs for probable cause of failure
# Traceback (most recent call last):
#   File "tmp/hadoop.py", line 76, in <module>
#     MRcoverage().run()
#   File "/opt/mrjob/mrjob/job.py", line 433, in run
#     mr_job.execute()
#   File "/opt/mrjob/mrjob/job.py", line 451, in execute
#     super(MRJob, self).execute()
#   File "/opt/mrjob/mrjob/launch.py", line 160, in execute
#     self.run_job()
#   File "/opt/mrjob/mrjob/launch.py", line 225, in run_job
#     runner.run()
#   File "/opt/mrjob/mrjob/runner.py", line 468, in run
#     self._run()
#   File "/opt/mrjob/mrjob/hadoop.py", line 275, in _run
#     self._run_job_in_hadoop()
#   File "/opt/mrjob/mrjob/hadoop.py", line 399, in _run_job_in_hadoop
#     raise CalledProcessError(returncode, step_args)
# subprocess.CalledProcessError: Command '['/usr/local/hadoop/bin/hadoop', 'jar', '/usr/local/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.6.0.jar', '-files', 'hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/files/setup-wrapper.sh#setup-wrapper.sh,hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/files/hadoop.py#hadoop.py', '-archives', 'hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/files/mrjob.tar.gz#mrjob.tar.gz', '-input', 'hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/files/ngs.sam.short', '-output', 'hdfs:///user/jovyan/tmp/mrjob/hadoop.jovyan.20151214.164022.701186/output', '-mapper', 'sh -ex setup-wrapper.sh python3 hadoop.py --step-num=0 --mapper', '-reducer', 'sh -ex setup-wrapper.sh python3 hadoop.py --step-num=0 --reducer']' returned non-zero exit status 256

# %% [markdown]
# ## Counters

# %% [markdown]
# ## Runners

# %% [markdown]
# You cannot use the programmatic runner functionality in the same file as your job class. As an example of what not to do, here is some code that does not work.
