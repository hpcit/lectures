# %% [markdown]
# # A more pythonic MapReduce

# %% [markdown]
# With Hadoop Streaming we switched MapReduce from Java to Python.
#
# How could we improve some more?
#
# What problems do we deal with?

# %% [markdown]
# We have to directly deal with HDFS
# * move input files
# * recover outputs
# * human make mistakes

# %% [markdown]
# Not easy debugging
#
# * logs via jobtracker
# * errors are Java stacktrace, often unrelated with the real problem

# %% [markdown]
# We have to write two different files
# * one for the mapper
# * one for the reducer
# * not a **module**

# %% [markdown]
# Is there a Python part of the language that can help representing a MapReduce task?

# %%
# A python class

class myclass(object):
    
    a_property = 42
    
    def a_method(self):
        pass
    def another_method(self, var):
        print(var)

# %%
# Create instance of our class
instance = myclass()
# Use it
instance.a_method()
instance.another_method("test")
instance.a_property

# %%
class MapReduce(object):
    """ A MapReduce class prototype """
    
    def mapper(self, line):
        pass
    def reducer(self, sorted_line):
        pass

# %% [markdown]
# # MRJob
# A more pythonic MapReduce library from Yelp
#
# <img src='https://avatars1.githubusercontent.com/u/49071?v=3&s=400' width=300>

# %% [markdown]
# > “Easiest route to Python programs that run on Hadoop”
#
# Install with:
# ```bash
# pip install mrjob
# ```
#
# **Running modes**
# * Test your code locally without installing Hadoop
# * or run it on a cluster of your choice!
#     - Integrates with Amazon **Elastic MapReduce** (EMR)
#     - same code with local, Hadoop, EMR
#     - easy to run your job in the cloud as on your laptop

# %% [markdown]
# ### How does MrJob work?
#
# * Python module built **on top of Hadoop Streaming**
#     - HS jar opens a subprocess to your code
#     - sends it input via stdin
#     - gathers results via stdout
# * Wrap HDFS pre and post processing if hadoop exists
# * a consistent interface across every environment it supports
# * automatically serializes/deserializes data flow out of each task
#     - e.g. JSON: json.loads() and json.dumps()

# %% [markdown]
# ## Getting hands dirty

# %%
from mrjob.job import MRJob

# %% [markdown]
# A job is defined by a class extended from MRJob package
#
# * Contains methods that define the steps of a Hadoop job
# * A “step” consists of a mapper, a combiner, and a reducer.
# * All of those  are optional, though you must have at least one.

# %%
class myjob(MRJob):
    def mapper(self, _, line):
        pass
    def combiner(self, key, values):
        pass
    def reducer(self, key, values):
        pass
    def steps(self):
        return [ MRStep(mapper=self.mapper, combiner=self.combiner, reducer=self.reducer) ]

# %% [markdown]
# ## WordCount

# %% [markdown]
# ### Mapper
#
# The mapper() method takes a key and a value as args
#
# ```
#     def mapper(self, _, line):
#         pass
# ```
#
# * E.g. key is ignored and a single line of text input is the value
#
# * Yields as many key-value pairs as it likes

# %% [markdown]
# ### Yield?
#
# **Warning**: `yield` != `return`
#
# > yield return a generator, the one you usually use with  ```print i; for i in generator```
#
# Example
# ```python
# def mygen():
#     for i in range(1,10):
#     # THIS IS WHAT HAPPENS INSIDE THE MAPPER/REDUCER
#         yield i, “value”
#
# for key, value in mygen():
#     print key, value
# ```

# %% [markdown]
# ### Reducer
#
# The reduce() method takes a key and an iterator of values
#
# ```
#     def reducer(self, key, values):
#         pass
# ```
#
# * Also yields as many key-value pairs as it likes
#     * E.g. it sums the values for each key
# * Represent the  numbers of characters, words, and lines in the initial input

# %% [markdown]
# ## Let's write our job

# %%
# Little configuration

mydir = "mymrjob"
# %env mydir = $mydir
myinput = "/data/worker/books/twolines.txt"
# %env myinput $myinput
myscript = mydir + "/wordcount.py"
# %env myscript $myscript

# %system mkdir -p $mydir
# %env myoutput $mydir/out.txt
# %env mylog $mydir/out.log
# Out:
# env: mydir=mymrjob
# env: myinput=/data/worker/books/twolines.txt
# env: myscript=mymrjob/wordcount.py
# env: myoutput=mymrjob/out.txt
# env: mylog=mymrjob/out.log

# %% [markdown]
# Create the job file

# %%
# %%writefile $myscript
#
# from mrjob.job import MRJob
# class MRWordCount(MRJob):
#     """ Wordcount with MapReduce in a pythonic way"""
#
#     def mapper(self, key, line):
#         for word in line.split(' '):
#              yield word.lower(), 1
#
#     def reducer(self, word, occurrences):
#         yield word, sum(occurrences)
#
# if __name__ == '__main__':
#     MRWordCount.run()
# Out:
# Overwriting mymrjob/wordcount.py

# %% [markdown]
# Note!
#
# Thanks to MrJob and generators we do not care inside the reducer to check when the value is changing.

# %% [markdown]
# ## I/O
#
# You can pass input via stdin but be aware that mrjob will just dump it to a file first:
# ```bash
# $ python my_job.py < input.txt
# ```
#
# You can pass multiple input files, mixed with stdin (using the – character)
# ```bash
# $ python my_job.py input1.txt input2.txt - < input3.txt
# ```
#
# By default, output will be written to stdout.
# ```bash
# $ python my_job.py input.txt
# ```

# %%
# Execute MrJob
! python $myscript $myinput 1> $myoutput 2> $mylog

# %% [markdown]
# Note again: if this comand takes minutes, you may go to see what is happening in your Hadoop JobTracker
# http://localhost:8088/cluster

# %%
# %cat $myoutput
# Out:
# "bye"	1
# "goodbye"	1
# "hadoop"	2
# "hello"	2
# "world"	2

# %%
# %cat $mylog
# Out:
# Unexpected option hdfs_tmp_dir
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# creating tmp directory /tmp/wordcount.root.20151013.105600.184640
# writing wrapper script to /tmp/wordcount.root.20151013.105600.184640/setup-wrapper.sh
# Using Hadoop version 2.6.0
# Copying local files into hdfs:///user/root/tmp/mrjob/wordcount.root.20151013.105600.184640/files/
# HADOOP: packageJobJar: [/tmp/hadoop-unjar7755496883310791297/] [] /tmp/streamjob2462321277901270862.jar tmpDir=null
# HADOOP: Connecting to ResourceManager at /0.0.0.0:8032
# HADOOP: Connecting to ResourceManager at /0.0.0.0:8032
# HADOOP: Total input paths to process : 1
# HADOOP: number of splits:2
# HADOOP: Submitting tokens for job: job_1444732540385_0001
# HADOOP: Submitted application application_1444732540385_0001
# HADOOP: The url to track the job: http://ipyhadoop:8088/proxy/application_1444732540385_0001/
# HADOOP: Running job: job_1444732540385_0001
# HADOOP: Job job_1444732540385_0001 running in uber mode : false
# HADOOP:  map 0% reduce 0%
# HADOOP:  map 100% reduce 0%
# HADOOP:  map 100% reduce 100%
# HADOOP: Job job_1444732540385_0001 completed successfully
# HADOOP: Counters: 49
# HADOOP: 	File System Counters
# HADOOP: 		FILE: Number of bytes read=104
# HADOOP: 		FILE: Number of bytes written=333792
# HADOOP: 		FILE: Number of read operations=0
# HADOOP: 		FILE: Number of large read operations=0
# HADOOP: 		FILE: Number of write operations=0
# HADOOP: 		HDFS: Number of bytes read=374
# HADOOP: 		HDFS: Number of bytes written=51
# HADOOP: 		HDFS: Number of read operations=9
# HADOOP: 		HDFS: Number of large read operations=0
# HADOOP: 		HDFS: Number of write operations=2
# HADOOP: 	Job Counters
# HADOOP: 		Launched map tasks=2
# HADOOP: 		Launched reduce tasks=1
# HADOOP: 		Data-local map tasks=2
# HADOOP: 		Total time spent by all maps in occupied slots (ms)=11040
# HADOOP: 		Total time spent by all reduces in occupied slots (ms)=3901
# HADOOP: 		Total time spent by all map tasks (ms)=11040
# HADOOP: 		Total time spent by all reduce tasks (ms)=3901
# HADOOP: 		Total vcore-seconds taken by all map tasks=11040
# HADOOP: 		Total vcore-seconds taken by all reduce tasks=3901
# HADOOP: 		Total megabyte-seconds taken by all map tasks=11304960
# HADOOP: 		Total megabyte-seconds taken by all reduce tasks=3994624
# HADOOP: 	Map-Reduce Framework
# HADOOP: 		Map input records=2
# HADOOP: 		Map output records=8
# HADOOP: 		Map output bytes=82
# HADOOP: 		Map output materialized bytes=110
# HADOOP: 		Input split bytes=300
# HADOOP: 		Combine input records=0
# HADOOP: 		Combine output records=0
# HADOOP: 		Reduce input groups=5
# HADOOP: 		Reduce shuffle bytes=110
# HADOOP: 		Reduce input records=8
# HADOOP: 		Reduce output records=5
# HADOOP: 		Spilled Records=16
# HADOOP: 		Shuffled Maps =2
# HADOOP: 		Failed Shuffles=0
# HADOOP: 		Merged Map outputs=2
# HADOOP: 		GC time elapsed (ms)=240
# HADOOP: 		CPU time spent (ms)=2260
# HADOOP: 		Physical memory (bytes) snapshot=526491648
# HADOOP: 		Virtual memory (bytes) snapshot=2127994880
# HADOOP: 		Total committed heap usage (bytes)=280240128
# HADOOP: 	Shuffle Errors
# HADOOP: 		BAD_ID=0
# HADOOP: 		CONNECTION=0
# HADOOP: 		IO_ERROR=0
# HADOOP: 		WRONG_LENGTH=0
# HADOOP: 		WRONG_MAP=0
# HADOOP: 		WRONG_REDUCE=0
# HADOOP: 	File Input Format Counters
# HADOOP: 		Bytes Read=74
# HADOOP: 	File Output Format Counters
# HADOOP: 		Bytes Written=51
# HADOOP: Output directory: hdfs:///user/root/tmp/mrjob/wordcount.root.20151013.105600.184640/output
# looking for job logs in /usr/local/hadoop/logs/history/
# Counters from step 1:
#   (no counters found)
# Streaming final output from hdfs:///user/root/tmp/mrjob/wordcount.root.20151013.105600.184640/output
# removing tmp directory /tmp/wordcount.root.20151013.105600.184640
# deleting hdfs:///user/root/tmp/mrjob/wordcount.root.20151013.105600.184640 from HDFS

# %% [markdown]
# Here's an empty **template** to work with in copy/paste

# %%
# %%writefile SPECIFY_A_FILENAME.py
#!/usr/bin/env python
# -*- coding: utf-8 -*-
""" MapReduce easily with Python """

from mrjob.job import MRJob
from mrjob.step import MRStep

class job(MRJob):
    def mapper(self, _, line):
        pass
    def reducer(self, key, line):
        pass
    def steps(self):
        return [ MRStep(mapper=self.mapper, reducer=self.reducer)]

if __name__ == "__main__":
    job.run()

# %% [markdown]
# ## Exercise
#
# Convert your exercise for vowels inside the divine comedy into MrJob class

# %% [markdown]
# ## Running on Hadoop

# %% [markdown]
# By default, mrjob will run your job on your local (normal) environment) in a single Python process
#
# You change the way the job is run with the `-r/--runner` option:
#
# ```
# -r inline, -r local, -r hadoop, or -r emr
# ```
#
# Use also `--verbose` option to show all the steps

# %% [markdown]
# So we just need to add `-r hadoop`.
#
# <small>Note: The `capture` *magic* is another way we could handle output.</small>

# %%
# %%capture hadoop_out
# Execute MrJob on Hadoop and let the magic handle outputs
! python $myscript $myinput -r hadoop 2> $mylog

# %%
hadoop_out.show()
# Out:
# "bye"	1
# "goodbye"	1
# "hadoop"	2
# "hello"	2
# "world"	2

# %%
# %cat $mylog
# Out:
# Unexpected option hdfs_tmp_dir
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# creating tmp directory /tmp/wordcount.root.20151013.130840.424615
# writing wrapper script to /tmp/wordcount.root.20151013.130840.424615/setup-wrapper.sh
# Using Hadoop version 2.6.0
# Copying local files into hdfs:///user/root/tmp/mrjob/wordcount.root.20151013.130840.424615/files/
# HADOOP: packageJobJar: [/tmp/hadoop-unjar6938543500754848653/] [] /tmp/streamjob3313232432800080753.jar tmpDir=null
# HADOOP: Connecting to ResourceManager at /0.0.0.0:8032
# HADOOP: Connecting to ResourceManager at /0.0.0.0:8032
# HADOOP: Total input paths to process : 1
# HADOOP: number of splits:2
# HADOOP: Submitting tokens for job: job_1444732540385_0005
# HADOOP: Submitted application application_1444732540385_0005
# HADOOP: The url to track the job: http://ipyhadoop:8088/proxy/application_1444732540385_0005/
# HADOOP: Running job: job_1444732540385_0005
# HADOOP: Job job_1444732540385_0005 running in uber mode : false
# HADOOP:  map 0% reduce 0%
# HADOOP:  map 100% reduce 0%
# HADOOP:  map 100% reduce 100%
# HADOOP: Job job_1444732540385_0005 completed successfully
# HADOOP: Counters: 49
# HADOOP: 	File System Counters
# HADOOP: 		FILE: Number of bytes read=104
# HADOOP: 		FILE: Number of bytes written=333792
# HADOOP: 		FILE: Number of read operations=0
# HADOOP: 		FILE: Number of large read operations=0
# HADOOP: 		FILE: Number of write operations=0
# HADOOP: 		HDFS: Number of bytes read=374
# HADOOP: 		HDFS: Number of bytes written=51
# HADOOP: 		HDFS: Number of read operations=9
# HADOOP: 		HDFS: Number of large read operations=0
# HADOOP: 		HDFS: Number of write operations=2
# HADOOP: 	Job Counters
# HADOOP: 		Launched map tasks=2
# HADOOP: 		Launched reduce tasks=1
# HADOOP: 		Data-local map tasks=2
# HADOOP: 		Total time spent by all maps in occupied slots (ms)=9369
# HADOOP: 		Total time spent by all reduces in occupied slots (ms)=3376
# HADOOP: 		Total time spent by all map tasks (ms)=9369
# HADOOP: 		Total time spent by all reduce tasks (ms)=3376
# HADOOP: 		Total vcore-seconds taken by all map tasks=9369
# HADOOP: 		Total vcore-seconds taken by all reduce tasks=3376
# HADOOP: 		Total megabyte-seconds taken by all map tasks=9593856
# HADOOP: 		Total megabyte-seconds taken by all reduce tasks=3457024
# HADOOP: 	Map-Reduce Framework
# HADOOP: 		Map input records=2
# HADOOP: 		Map output records=8
# HADOOP: 		Map output bytes=82
# HADOOP: 		Map output materialized bytes=110
# HADOOP: 		Input split bytes=300
# HADOOP: 		Combine input records=0
# HADOOP: 		Combine output records=0
# HADOOP: 		Reduce input groups=5
# HADOOP: 		Reduce shuffle bytes=110
# HADOOP: 		Reduce input records=8
# HADOOP: 		Reduce output records=5
# HADOOP: 		Spilled Records=16
# HADOOP: 		Shuffled Maps =2
# HADOOP: 		Failed Shuffles=0
# HADOOP: 		Merged Map outputs=2
# HADOOP: 		GC time elapsed (ms)=226
# HADOOP: 		CPU time spent (ms)=2390
# HADOOP: 		Physical memory (bytes) snapshot=517996544
# HADOOP: 		Virtual memory (bytes) snapshot=2138722304
# HADOOP: 		Total committed heap usage (bytes)=280240128
# HADOOP: 	Shuffle Errors
# HADOOP: 		BAD_ID=0
# HADOOP: 		CONNECTION=0
# HADOOP: 		IO_ERROR=0
# HADOOP: 		WRONG_LENGTH=0
# HADOOP: 		WRONG_MAP=0
# HADOOP: 		WRONG_REDUCE=0
# HADOOP: 	File Input Format Counters
# HADOOP: 		Bytes Read=74
# HADOOP: 	File Output Format Counters
# HADOOP: 		Bytes Written=51
# HADOOP: Output directory: hdfs:///user/root/tmp/mrjob/wordcount.root.20151013.130840.424615/output
# looking for job logs in /usr/local/hadoop/logs/history/
# Counters from step 1:
#   (no counters found)
# Streaming final output from hdfs:///user/root/tmp/mrjob/wordcount.root.20151013.130840.424615/output
# removing tmp directory /tmp/wordcount.root.20151013.130840.424615
# deleting hdfs:///user/root/tmp/mrjob/wordcount.root.20151013.130840.424615 from HDFS

# %% [markdown]
# ## An example of creating notebook extensions

# %% [markdown]
# A pattern recurs often:
#
# * You have to write a file
# * You have to execute mrjob
#     - with or without hadoop parameter
# * You have to bring back the output
#
# Can we do this with an ipython magic?

# %% [markdown]
# ### A MrJob dedicated extension
#
# Since there is none,
# we created an extension for helping users with mapreduce in Jupyter Notebook

# %%
# Load the extension
# %reload_ext mrjobmagic
# note: reload_ext does not get error if you try two times

# %% [markdown]
# How it works:
#
# * Cell extension
#
# ```
# %%mapreduce LOCAL_INPUT [inline,hadoop]
#
# MAPPER function
# [COMBINER function]
# REDUCER function
# ```
#
# * Line extension
#
# ```
# %mapreduce LOCAL_INPUT MR_FILE [inline,hadoop]
# ```

# %%
# %mapreduce?

# %%
myfile = '/data/worker/books/prince.txt'

# %%
# %%mapreduce $myfile
#
# def mapper(self, _, line):
#     pass
# def reducer(self, key, line):
#     pass
# Out:
# Input file is: /data/worker/books/prince.txt
# Saving the python class in: jobs/script_000006905.py
# Executing Mrjob.
# Done!
#
# Files:
# jobs/script_000006905.py      jobs/script_000006905.py.out
# jobs/script_000006905.py.err
# ''

# %% [markdown]
# Comparing with Hadoop Streaming :)
#
# ``` bash
# $ hadoop jar $HADOOP_HOME/hadoop-streaming.jar \
#     -files mapper.py,reducer.py
#     -input input_dir/ \
#     -output output_dir/ \
#     -mapper mapper.py \
#     -reducer reducer.py \
# ```

# %% [markdown]
# A real example with the extension

# %%
# %%mapreduce $myfile
# def mapper(self, key, line):
#     for word in line.split(' '):
#         yield word.lower(), 1
#
# def reducer(self, word, occurrences):
#     yield word, sum(occurrences)
# Out:
# Input file is: /data/worker/books/prince.txt
# Saving the python class in: jobs/script_000061748.py
# Executing Mrjob.
# Done!
#
# Files:
# jobs/script_000061748.py      jobs/script_000061748.py.out
# jobs/script_000061748.py.err
# {'': 2016,
#  '6': 2,
#  'probably': 1,
#  'tumult': 3,
#  'win': 9,
#  'dependent': 1,
#  'spent': 3,
#  'borgia': 5,
#  'propitious': 1,
#  'approach,': 1,
#  'faithful,': 5,
#  'private': 19,
#  'bianchi': 2,
#  '1.f.5.': 1,
#  'louis.': 1,
#  'indifferently': 1,
#  'commenting': 1,
#  'convention,': 1,
#  '(does': 1,
#  'defeat,': 2,
#  'dispersed': 2,
#  'resistance.': 1,
#  '1523': 1,
#  'egyptians,': 1,
#  'blushing': 1,
#  'proof': 3,
#  'eaten': 1,
#  'fill': 1,
#  'have.': 2,
#  'ebook': 5,
#  'inflicting': 1,
#  'attributed': 5,
#  'switzers,': 4,
#  'honourably,': 1,
#  '(\\"the': 1,
#  'sinigalia.': 3,
#  'rovere': 1,
#  'hindered': 2,
#  'bed': 2,
#  'submit': 3,
#  'detriment': 1,
#  'giuliano.': 1,
#  'invalidity': 1,
#  'compassionate': 1,
#  'control': 4,
#  '1.f.4.': 1,
#  'felt': 1,
#  'conspiracy.': 1,
#  'anger': 2,
#  'father,': 3,
#  'you!)': 1,
#  'malcontents,': 1,
#  'maximilian,(*)': 1,
#  'deliver': 2,
#  'intoxicated.': 1,
#  'dominions': 5,
#  'amongst': 8,
#  'send,': 1,
#  'passerini,': 1,
#  'everybody': 2,
#  'opening': 1,
#  'footsteps': 1,
#  'durable.': 1,
#  'longer,': 3,
#  'nearer': 1,
#  'locations.': 1,
#  'misled': 1,
#  'planned': 1,
#  'to.': 1,
#  'ranks?': 1,
#  '\\"catherine': 1,
#  'wolves.': 2,
#  'behave': 1,
#  'reformed': 1,
#  'paltry': 1,
#  'absence.': 1,
#  'bowshot': 1,
#  'alone': 5,
#  'italy,(*)': 1,
#  'steep,': 1,
#  'plea,': 1,
#  'requirements': 2,
#  'case,': 3,
#  'redemption,': 1,
#  'time-serving;': 1,
#  'answered:': 5,
#  'charged': 1,
#  'book],': 1,
#  'earned,': 1,
#  'heliogabalus,': 2,
#  'austere': 1,
#  'hundreds': 1,
#  'gherardesca': 1,
#  'medicean': 3,
#  'moses;': 1,
#  'delle': 4,
#  'urbino;': 1,
#  'houses,': 1,
#  'solicit': 2,
#  'demand': 4,
#  'roman': 16,
#  'government.': 4,
#  'physical': 2,
#  'distinguished': 3,
#  'callings': 1,
#  'beginning,': 1,
#  'principalities;': 1,
#  'cruel;': 1,
#  'individual;': 1,
#  'makes': 7,
#  'showed,': 1,
#  'accepted': 5,
#  'exchange': 1,
#  'deaths,': 1,
#  'vulgar,': 1,
#  'syracuse': 1,
#  'converting': 1,
#  'result.': 1,
#  'notions': 1,
#  'enveloped': 1,
#  'bring': 20,
#  'method.': 1,
#  'death--a': 1,
#  'kindnesses,': 1,
#  'former': 16,
#  'parliament': 1,
#  'rise,': 1,
#  'marriage': 2,
#  'incurred,': 1,
#  'cheated': 1,
#  'pasolini,': 1,
#  'save': 5,
#  'victorious,\\': 1,
#  'law,': 1,
#  'superior': 2,
#  'annexed': 3,
#  'endeavoured': 2,
#  'acquisition.': 1,
#  'one),': 1,
#  'act,': 1,
#  'restrain': 1,
#  'founder': 1,
#  'stripped': 1,
#  'nurse': 1,
#  'none': 14,
#  'turn.': 2,
#  'really': 3,
#  'contend': 1,
#  'advantages': 1,
#  'describes': 1,
#  'vita': 1,
#  'scruple': 1,
#  'implied,': 1,
#  'an': 90,
#  'consume': 2,
#  'trial;': 1,
#  'wide': 2,
#  '1.e.1': 3,
#  'longest': 1,
#  'fatigue': 2,
#  'attains': 1,
#  'liberality,': 4,
#  'englishman': 2,
#  'became': 29,
#  'indignity': 1,
#  'carried': 5,
#  'kingdoms': 2,
#  'raising': 1,
#  'himself;': 1,
#  'weather': 1,
#  'insurrections': 1,
#  'vitality,': 1,
#  'met': 7,
#  'prevented': 1,
#  'search': 1,
#  'daily,': 2,
#  'accomplished': 5,
#  'encouragement': 2,
#  'seventeenth': 1,
#  'weakness': 2,
#  'magistrates;': 1,
#  'jacopo': 6,
#  'trattare': 1,
#  'author,': 1,
#  'master': 14,
#  'words,': 2,
#  'antiquity': 2,
#  'otherwise': 9,
#  'end;': 1,
#  'avail,': 1,
#  'repeated,': 1,
#  '1328,': 2,
#  'catholic,\\': 1,
#  'night;': 2,
#  'italy': 26,
#  'cowardice.': 1,
#  'editions': 3,
#  'pest,': 1,
#  '1501;': 1,
#  'electronic': 27,
#  'get': 20,
#  'custom,': 1,
#  '1510;': 1,
#  '84116,': 1,
#  'embroil': 1,
#  'true,': 1,
#  'top': 1,
#  'care,': 4,
#  'duca': 2,
#  'russia': 1,
#  'relies': 1,
#  'lived': 8,
#  'count': 7,
#  'tuscany.': 2,
#  'john': 2,
#  'envoys': 3,
#  'kingdom.': 3,
#  '\\"company': 1,
#  'favours;': 1,
#  'auxiliaries.': 1,
#  'confirming': 1,
#  'inferiority': 1,
#  'beloved': 4,
#  'prato': 1,
#  'streets;': 1,
#  'summit': 2,
#  'hat.': 1,
#  'god': 16,
#  'steep': 1,
#  'fearing,': 1,
#  'but,': 11,
#  '($)': 1,
#  'soldier': 1,
#  'urge': 1,
#  '\\"i': 5,
#  'severities(*)': 1,
#  'christian': 1,
#  'reaching': 3,
#  'corrupted;': 1,
#  'saul': 2,
#  'alberico': 1,
#  'summit.': 1,
#  'pontificate,': 1,
#  'florio:': 1,
#  'magnificence.': 1,
#  'beginning': 12,
#  'hand-to-hand': 1,
#  '\\"high': 1,
#  'royalty': 3,
#  '1502,': 2,
#  'greater': 15,
#  'antiochus': 5,
#  'whale\\";': 1,
#  'governments': 3,
#  'replacement': 5,
#  'anastagio': 1,
#  'service': 3,
#  'tired': 1,
#  'checks,': 1,
#  'strike': 1,
#  'shelter': 2,
#  'meeting,': 1,
#  'decrease.': 1,
#  'surrendered': 1,
#  '1457.': 1,
#  'either;': 1,
#  'proprium': 1,
#  'compassion,': 1,
#  '10': 2,
#  '\\"in': 1,
#  'delightful': 2,
#  'cast': 1,
#  'venice': 2,
#  'proves': 2,
#  'consuming': 1,
#  'hereditary': 9,
#  'begins': 1,
#  'promising': 1,
#  'places,': 2,
#  'pairs': 1,
#  'woman-like,': 1,
#  'difficult': 14,
#  'event': 1,
#  'wicked,\\': 1,
#  'despoiled,': 2,
#  '1470,': 1,
#  'peril': 3,
#  'number': 11,
#  'seeing': 18,
#  'mind': 17,
#  'allege': 1,
#  'permission;': 1,
#  'begets': 1,
#  'beheld': 1,
#  'lets': 1,
#  'celebrating': 1,
#  'both.': 2,
#  'labour': 1,
#  'knowing': 10,
#  'reads': 1,
#  'say,': 6,
#  'difficulties;': 1,
#  'rouen': 3,
#  'conscious': 1,
#  "one's": 6,
#  'driven': 16,
#  'fate': 2,
#  '(and': 2,
#  'revolutions': 1,
#  'concerned': 1,
#  'hated,': 2,
#  'enrico.': 1,
#  'hunted': 1,
#  'wisdom,': 1,
#  'thirty-one': 1,
#  'presentation': 1,
#  'happy.': 2,
#  'goodwill': 6,
#  'remain': 12,
#  'defeated': 2,
#  'royal': 1,
#  "monarch's": 1,
#  'afterwards': 32,
#  'characteristic,': 1,
#  'factions;': 2,
#  'danger.': 1,
#  'sternness': 1,
#  'vincula,': 2,
#  'repeat,': 1,
#  'age,': 2,
#  'army;': 5,
#  'cities': 12,
#  'youth,': 2,
#  'came.': 1,
#  'world.': 1,
#  'furnished': 1,
#  'seized.': 1,
#  'bridge,': 1,
#  'armies.': 1,
#  'gather': 1,
#  'transcribe': 1,
#  'conclusions.': 1,
#  'disclaimer': 3,
#  'mankind.': 1,
#  'sharp': 2,
#  'latin': 1,
#  'signification': 1,
#  'death': 26,
#  'aylmer': 1,
#  'marked': 2,
#  'moral': 3,
#  'format': 4,
#  'deeds.': 1,
#  'unexpectedly,': 1,
#  'sanjaks,': 1,
#  'egypt': 1,
#  'resided': 3,
#  'prose,': 1,
#  'increasing': 4,
#  '(i.e.': 1,
#  'side': 12,
#  'meet': 7,
#  'gladiators,': 1,
#  'guards': 1,
#  'dianora': 1,
#  'partiundis': 1,
#  'steps': 2,
#  'and': 1905,
#  'cleverly': 1,
#  'xxi': 1,
#  'things.': 2,
#  'prose': 1,
#  'out;': 3,
#  'remaining': 3,
#  'usually': 1,
#  'reading': 2,
#  'tightly': 1,
#  'men,': 30,
#  'mississippi': 1,
#  'particularly': 4,
#  '1510.': 3,
#  'defensive': 1,
#  'praised': 5,
#  'obsolete,': 1,
#  'willingness,': 1,
#  'fact,': 1,
#  'promulgated.': 1,
#  'agrees': 1,
#  'these,': 1,
#  'character.': 2,
#  'territories,': 1,
#  'determined': 4,
#  'wishing,': 1,
#  'foothold': 2,
#  'through': 37,
#  'revolution.': 1,
#  'consideration': 3,
#  '\\"guilds': 1,
#  'conformed': 1,
#  'inhabitants;': 1,
#  'measures;': 2,
#  'undoes': 1,
#  'merchantibility': 1,
#  'battle': 14,
#  'recollection,': 1,
#  'cry': 4,
#  'fishes,': 1,
#  'ii),': 1,
#  'certainty': 1,
#  'proprietary': 1,
#  'lodovico': 2,
#  'florence': 28,
#  'unhappy': 1,
#  'sow': 1,
#  '501(c)(3)': 2,
#  'rules': 9,
#  'courage,': 5,
#  'servants,': 3,
#  'me.\\': 1,
#  'effecting': 2,
#  'inhumanity': 2,
#  'ornaments': 1,
#  'last': 7,
#  'death.': 5,
#  'exterminating': 1,
#  'destroys': 1,
#  'exists': 1,
#  'gracious': 1,
#  'ranks': 2,
#  'for,': 6,
#  'declaring': 1,
#  'wisdom.': 1,
#  'bologna:': 1,
#  'asia': 1,
#  'gentlemen': 4,
#  'disorder,': 1,
#  'professed': 1,
#  'passed,': 1,
#  "d'euna,": 1,
#  'credit': 4,
#  'citizens--this': 1,
#  'serezzana.': 1,
#  'destroying': 1,
#  'join': 4,
#  'rewarding': 1,
#  'behind': 2,
#  'abiding': 1,
#  'impetuous;': 1,
#  'responsible': 1,
#  'named': 4,
#  'confining': 1,
#  'catherine': 1,
#  'vice': 1,
#  'cited': 2,
#  'similarly,': 2,
#  'variable,': 1,
#  'understand': 13,
#  'gratify': 1,
#  'canti': 1,
#  'passage': 4,
#  'ears': 1,
#  'indeed,': 1,
#  'necromancer,\\': 1,
#  'ugucionne': 1,
#  'worth.': 1,
#  'kingdom': 23,
#  'cavalry--having': 1,
#  'tied': 1,
#  'slaughtered': 1,
#  'length;': 1,
#  'entrance': 1,
#  'december,': 1,
#  'simple.': 1,
#  'spoken': 5,
#  'you,': 16,
#  'demonstrate': 1,
#  'cambrai,': 1,
#  'swift': 1,
#  'spanish': 3,
#  'wild': 1,
#  'bragged': 1,
#  'houses': 4,
#  'union': 1,
#  'earthen': 1,
#  '1.': 2,
#  'parts,': 1,
#  'violence,': 4,
#  'f.': 3,
#  'obey': 6,
#  'lucca,': 19,
#  'formidable,': 1,
#  'parties': 6,
#  'rally': 2,
#  'winds': 1,
#  'tactics': 1,
#  'lords,': 1,
#  'unusual': 1,
#  'theirs,': 1,
#  'ammazzare': 2,
#  'adds': 2,
#  'treatise': 1,
#  'burgundy,': 1,
#  'more': 150,
#  'safer': 3,
#  'ignored': 1,
#  'delicate': 1,
#  'corporation': 2,
#  'africa': 1,
#  'however,': 4,
#  'fortunati': 1,
#  'distance': 1,
#  'use': 27,
#  'odious': 1,
#  'champion,': 1,
#  'knights': 1,
#  'perhaps,': 1,
#  'sienese--everybody': 1,
#  'celebrated': 2,
#  'periodic': 1,
#  'name': 10,
#  'hard': 1,
#  'angered': 2,
#  'vices': 5,
#  'dealing': 1,
#  'bad,': 3,
#  'send': 14,
#  'men.': 6,
#  'irrevocable,': 1,
#  'you': 201,
#  'son': 20,
#  'albinus': 3,
#  'directed': 3,
#  'states--a': 1,
#  'albizzi,': 1,
#  'slay': 1,
#  'loss': 6,
#  'arose,': 1,
#  'fidelity,': 1,
#  'perceive': 1,
#  'little.': 1,
#  '30th': 1,
#  'adventurous': 2,
#  'successor,': 2,
#  'constant': 2,
#  'infinite': 5,
#  '\\"many': 1,
#  'contented,': 1,
#  'signor': 3,
#  'overreached': 1,
#  'types': 1,
#  'soul,': 2,
#  'lie,': 1,
#  'forli': 1,
#  'altogether': 3,
#  'purpose': 2,
#  'narrowness': 1,
#  'hands;': 1,
#  'opizi,': 1,
#  'its': 62,
#  'delight;': 1,
#  'freely,': 1,
#  'violent,': 1,
#  'check': 3,
#  'wheeled': 1,
#  'captains.': 2,
#  'boundless': 1,
#  'make': 72,
#  'tower': 2,
#  'included.': 1,
#  'taddeo': 3,
#  'pescia,': 1,
#  'states,': 9,
#  'used.': 2,
#  'to': 2099,
#  'astuteness': 1,
#  'commended': 1,
#  'religious.': 1,
#  'success': 3,
#  'attempts': 1,
#  'after,': 1,
#  'achilles': 1,
#  'wondering': 2,
#  'sooner': 5,
#  'rome;': 1,
#  'volunteer': 1,
#  'reputed': 4,
#  'alamanni': 1,
#  'losing': 1,
#  'charles': 11,
#  'unaspiring': 1,
#  'rapacity': 2,
#  'collected': 1,
#  'avail': 3,
#  'get,': 1,
#  '\\"contro': 2,
#  'strengthen': 2,
#  'lacks': 2,
#  'designate': 1,
#  'effeminate,': 1,
#  'irresolute': 2,
#  'yourself,': 2,
#  'peaceful': 2,
#  'frenchmen': 2,
#  'overcome,': 1,
#  'occupations': 1,
#  'suggested': 1,
#  'wanting;': 1,
#  'stefano': 7,
#  'great,': 7,
#  'mind,': 5,
#  'fancies': 1,
#  '1.e.7.': 1,
#  'playing': 1,
#  'centuries.': 1,
#  'display': 1,
#  'switzers': 5,
#  'calm': 1,
#  'conquest,': 1,
#  'powerful': 14,
#  'sons': 4,
#  'reports,': 1,
#  'mountaineers,': 1,
#  '1442,': 1,
#  'necessary': 54,
#  'honoured,': 2,
#  'sending': 3,
#  'satisfied.': 1,
#  'want': 5,
#  'induce': 1,
#  'recall': 7,
#  'macedon': 1,
#  'wishes,(*)': 1,
#  'debatable': 1,
#  'good,': 7,
#  'principles': 3,
#  'assisted,': 1,
#  'giovanni': 16,
#  'right': 8,
#  'ready': 11,
#  'allies': 1,
#  'imposed': 1,
#  'plain.': 1,
#  'walls': 2,
#  'glass': 1,
#  'tempest),': 1,
#  'faithful;': 1,
#  'ill-treatment': 1,
#  'crosses': 1,
#  'average': 2,
#  'fraud,': 1,
#  'spain,': 5,
#  'opponents,': 2,
#  'diligence,': 1,
#  'fail;': 1,
#  'venetians--although': 1,
#  'towards': 18,
#  'willingness': 1,
#  'easily.': 2,
#  'reach.': 1,
#  'every': 59,
#  'examples.': 2,
#  'humbled,': 1,
#  'director': 1,
#  'rash,': 1,
#  'content': 7,
#  'statecraft,': 1,
#  'compelled': 17,
#  'than,': 1,
#  'remainder': 1,
#  'whatever,': 1,
#  'recur.': 1,
#  'lifetime,': 1,
#  'remained': 10,
#  'slept': 1,
#  'flanks.': 1,
#  '.': 9,
#  'using': 7,
#  'august': 1,
#  'giovanni;': 1,
#  'spectacles': 1,
#  'gloriously': 1,
#  '\\"when': 3,
#  'original': 1,
#  'dressed': 1,
#  'representing': 1,
#  'abject': 1,
#  'pull': 2,
#  'prince,\\': 6,
#  'elements': 1,
#  'is--not': 1,
#  'desirable': 2,
#  'widow,': 1,
#  'section': 7,
#  'cancel': 1,
#  'be': 467,
#  'fly,': 1,
#  'graces': 1,
#  'resolved,': 1,
#  'stout': 1,
#  '1527,': 2,
#  'do,': 7,
#  'admired,': 2,
#  'creation': 1,
#  'e.': 1,
#  'therefore': 34,
#  'deaths': 1,
#  'exercise': 7,
#  'uproar': 1,
#  'philip,': 1,
#  'arno': 3,
#  'greatness;': 1,
#  'god,': 2,
#  'xx': 1,
#  'societies,(*)': 1,
#  'seek': 5,
#  'people,\\': 1,
#  'inquired;': 1,
#  'under': 74,
#  'captains,': 3,
#  'possesses': 1,
#  'resolutions.': 2,
#  'mixed:': 1,
#  'ways': 9,
#  'discussion': 4,
#  'subsisting': 1,
#  "'wholly": 1,
#  'gazette,': 1,
#  'letter,': 1,
#  'nose?\\': 1,
#  'duke;': 3,
#  'fortify': 3,
#  'undertaking': 1,
#  'reference': 1,
#  'hurt': 1,
#  'powerful,': 4,
#  'fit': 1,
#  'stable': 1,
#  'implies': 1,
#  'accession': 1,
#  'redistributing': 2,
#  'error': 1,
#  'regions,': 1,
#  'occasional': 1,
#  'invasion': 1,
#  'fulfilled': 1,
#  'pupil,': 1,
#  'myself': 7,
#  'beasts;': 1,
#  'bergamo,': 1,
#  'choice;': 1,
#  'sovereignty': 2,
#  'baseness': 2,
#  'francis': 1,
#  'unfaithful,': 3,
#  'marquess': 1,
#  'france;': 3,
#  'sonetti,': 1,
#  'outwit': 1,
#  'gravity,': 1,
#  'this': 336,
#  'recognition': 1,
#  'odious,': 2,
#  'lasted': 2,
#  'explanation.': 1,
#  'hopes': 2,
#  'bold': 2,
#  'old': 25,
#  'been': 159,
#  'draws': 1,
#  'matters': 10,
#  'freely': 5,
#  'pass,': 2,
#  'lucchese,': 2,
#  'fixed': 5,
#  'complicity': 2,
#  'noticeable': 1,
#  "nell'": 1,
#  'captain;': 1,
#  'discipline.': 1,
#  'foundation\\': 1,
#  'yours,': 2,
#  'succeeded.': 1,
#  'away--you': 1,
#  'alone.': 1,
#  'servant': 5,
#  'istorie': 1,
#  'benefit': 1,
#  '1512': 2,
#  'acts': 2,
#  'extricating': 2,
#  'enormously': 1,
#  'vitelleschi,': 1,
#  'restrictions': 1,
#  'address': 2,
#  '1232.zip': 1,
#  'cities,': 1,
#  '\\"my': 1,
#  'vicissitudes': 1,
#  'influence;': 1,
#  'finally': 4,
#  'bernardo': 1,
#  'expedients': 1,
#  '1507-8,': 1,
#  'preserve': 4,
#  'directly': 2,
#  'along': 5,
#  'displaying': 3,
#  'estate.': 1,
#  'subjects.': 2,
#  'wickedness.': 1,
#  'speak,': 3,
#  'belfagor': 1,
#  'casavecchio': 2,
#  'boldness,': 1,
#  'cause.': 1,
#  'subjugated': 1,
#  'officiis\\":': 1,
#  'feet,\\': 1,
#  'brings': 4,
#  'sprang': 1,
#  '(which': 1,
#  'drew': 7,
#  'vain.': 1,
#  'ghibellines,': 2,
#  'either,': 2,
#  'religion.': 1,
#  'can,': 3,
#  'hears': 1,
#  'liberal;': 1,
#  'afraid': 4,
#  'majority': 1,
#  'delinquents,': 1,
#  'exile.': 1,
#  'brother.': 1,
#  'craft': 2,
#  'fede\\': 1,
#  'despised;': 1,
#  'enrico,': 2,
#  'spread': 2,
#  'necessity,': 2,
#  'pisa,': 16,
#  '1507)': 1,
#  'useful;': 1,
#  'speaks': 1,
#  'principality:': 1,
#  'reply': 4,
#  'victories': 2,
#  'www.gutenberg.org': 1,
#  'disclaimers': 1,
#  'lay,': 1,
#  'news': 4,
#  'consequent': 1,
#  'valdichiana': 1,
#  'we': 29,
#  'mouths': 2,
#  'natures,': 2,
#  'despairing': 1,
#  'influence,': 1,
#  'examined': 1,
#  '\\"intrattenere.\\': 1,
#  'display,': 1,
#  'rapidly': 4,
#  'http://gutenberg.org/license).': 1,
#  'lost.': 1,
#  'orsini': 19,
#  'republic': 5,
#  'defence,': 1,
#  'strength': 9,
#  'learning': 4,
#  'injuries.': 1,
#  'implied': 1,
#  'rebellious': 1,
#  '2': 1,
#  'xxiii': 1,
#  'signifies': 1,
#  'prove': 2,
#  '\\"florentine': 1,
#  'including': 8,
#  'liberate': 1,
#  'games': 1,
#  'presence': 2,
#  'suburb': 1,
#  'professor': 1,
#  'baglioni,': 2,
#  "wallace's": 1,
#  'beluarum;': 1,
#  'untie': 1,
#  'before,': 4,
#  'sicilian,': 1,
#  'aragon': 2,
#  'falconi': 1,
#  'miserly': 1,
#  'quarters': 5,
#  'cause': 20,
#  'state.': 8,
#  'occurrences': 1,
#  'evidences': 2,
#  'solid': 1,
#  'decade': 1,
#  'miracle': 1,
#  'scale,': 1,
#  'skill': 4,
#  'overthrow': 3,
#  'style': 1,
#  'upon': 55,
#  'yours.': 1,
#  'vii.': 2,
#  'xix': 1,
#  'expectation,': 2,
#  'crushing': 1,
#  'advantage,': 2,
#  'length,': 2,
#  'proverb': 1,
#  'disunion': 1,
#  'presumption': 1,
#  'time.': 4,
#  'self-government,': 1,
#  'show.': 2,
#  'customs,': 2,
#  'revolt': 2,
#  'established,': 1,
#  'genius.': 1,
#  'comedy': 3,
#  'protest': 1,
#  'treated': 4,
#  'provoked': 1,
#  'space': 3,
#  'offered': 3,
#  'preferred;': 1,
#  'outraged': 1,
#  'accredited': 1,
#  'lorqua.': 1,
#  'subscribe': 1,
#  'germans': 3,
#  'counsel;': 1,
#  'candales,': 1,
#  'florence\\': 2,
#  'compressed,': 1,
#  'hast': 9,
#  'horsemen': 6,
#  'goest': 2,
#  'victory,': 2,
#  'observe': 6,
#  'freer': 1,
#  'completed': 1,
#  '1423,': 1,
#  'auxiliaries': 3,
#  'poverty,': 1,
#  'firmly': 1,
#  'sections': 1,
#  'insolent': 1,
#  'ship': 1,
#  'magistracy,': 1,
#  'performances': 1,
#  'glorious': 1,
#  'interfering': 1,
#  '1513': 1,
#  'sforza,\\': 1,
#  'addresses.': 1,
#  'arises:': 1,
#  'number.': 1,
#  'conquering,': 1,
#  'bentivogli,': 5,
#  'party': 13,
#  'copyright': 13,
#  'centre': 3,
#  'leaving': 6,
#  'wishes.': 1,
#  'ut': 1,
#  'distance,': 1,
#  'infantry': 22,
#  'unguarded,': 1,
#  'abject,': 1,
#  'immense': 4,
#  'festivals': 1,
#  'witness': 3,
#  'captain': 8,
#  '216': 1,
#  'practise': 2,
#  'jeanne,': 1,
#  '1512.': 2,
#  'foster': 2,
#  'gravina': 4,
#  '1320': 1,
#  'idle,': 1,
#  'misfortunes': 1,
#  'dead,': 3,
#  'discover': 4,
#  'prestige': 1,
#  'san': 18,
#  'eleventh,(+)': 1,
#  'fate.': 1,
#  'rely': 12,
#  'shouts': 1,
#  'ebooks,': 2,
#  'squander': 1,
#  'deferential': 1,
#  'recognized.\\"--pall': 1,
#  'treacherous': 1,
#  'clearer,': 1,
#  ...}

# %%
# Recover last cell output
data = _

# %%
# Sort in descend based on values count
sorted(data.items(), key=lambda x: x[1], reverse=True) 
# note: values were already converted into integers
# Out:
# [('the', 3068),
#  ('to', 2099),
#  ('', 2016),
#  ('and', 1905),
#  ('of', 1796),
#  ('in', 987),
#  ('he', 904),
#  ('a', 774),
#  ('that', 692),
#  ('his', 638),
#  ('by', 504),
#  ('it', 500),
#  ('with', 487),
#  ('not', 486),
#  ('be', 467),
#  ('they', 437),
#  ('for', 436),
#  ('is', 428),
#  ('have', 386),
#  ('was', 376),
#  ('this', 336),
#  ('which', 334),
#  ('who', 328),
#  ('as', 324),
#  ('had', 290),
#  ('are', 284),
#  ('but', 277),
#  ('or', 271),
#  ('him', 267),
#  ('their', 266),
#  ('one', 263),
#  ('from', 233),
#  ('i', 209),
#  ('at', 208),
#  ('you', 201),
#  ('will', 201),
#  ('on', 199),
#  ('so', 195),
#  ('those', 194),
#  ('were', 190),
#  ('all', 185),
#  ('them', 180),
#  ('if', 178),
#  ('when', 176),
#  ('would', 165),
#  ('has', 162),
#  ('been', 159),
#  ('more', 150),
#  ('because', 147),
#  ('prince', 142),
#  ('being', 135),
#  ('should', 133),
#  ('other', 132),
#  ('any', 127),
#  ('than', 126),
#  ('men', 125),
#  ('no', 112),
#  ('there', 109),
#  ('may', 108),
#  ('having', 107),
#  ('such', 107),
#  ('these', 107),
#  ('can', 106),
#  ('castruccio', 101),
#  ('himself', 98),
#  ('many', 97),
#  ('only', 94),
#  ('against', 92),
#  ('do', 92),
#  ('ought', 91),
#  ('an', 90),
#  ('him,', 90),
#  ('own', 89),
#  ('great', 82),
#  ('always', 80),
#  ('into', 79),
#  ('project', 79),
#  ('them,', 78),
#  ('how', 77),
#  ('without', 77),
#  ('time', 76),
#  ('did', 75),
#  ('under', 74),
#  ('much', 73),
#  ('make', 72),
#  ('some', 72),
#  ('could', 72),
#  ('people', 71),
#  ('whom', 71),
#  ('out', 71),
#  ('either', 70),
#  ('what', 69),
#  ('duke', 67),
#  ('never', 67),
#  ('new', 66),
#  ('nor', 65),
#  ('cannot', 65),
#  ('its', 62),
#  ('good', 62),
#  ('every', 59),
#  ('therefore,', 58),
#  ('made', 57),
#  ('man', 57),
#  ('first', 57),
#  ('upon', 55),
#  ('king', 55),
#  ('take', 55),
#  ('necessary', 54),
#  ('your', 54),
#  ('gutenberg-tm', 54),
#  ('also', 53),
#  ('two', 52),
#  ('able', 52),
#  ('most', 51),
#  ('very', 50),
#  ('after', 50),
#  ('that,', 50),
#  ('thus', 50),
#  ('well', 50),
#  ('keep', 50),
#  ('order', 49),
#  ('hold', 49),
#  ('found', 49),
#  ('them.', 49),
#  ('way', 49),
#  ('state', 48),
#  ('both', 48),
#  ('work', 48),
#  ('although', 46),
#  ('fear', 46),
#  ('others', 45),
#  ('prince,', 45),
#  ('things', 44),
#  ('up', 44),
#  ('fortune', 43),
#  ('yet', 42),
#  ('whilst', 42),
#  ('does', 42),
#  ('before', 41),
#  ('florentines', 41),
#  ('where', 41),
#  ('it,', 41),
#  ('sent', 40),
#  ('then', 40),
#  ('must', 39),
#  ('wish', 38),
#  ('machiavelli', 38),
#  ('who,', 38),
#  ('(*)', 38),
#  ('messer', 38),
#  ('through', 37),
#  ('become', 36),
#  ('long', 36),
#  ('might', 36),
#  ('themselves', 35),
#  ('came', 35),
#  ('our', 35),
#  ('arms', 35),
#  ('princes', 35),
#  ('therefore', 34),
#  ('another', 34),
#  ('my', 34),
#  ('him.', 34),
#  ('considered', 34),
#  ('pope', 33),
#  ('she', 33),
#  ('shall', 33),
#  ('afterwards', 32),
#  ('little', 32),
#  ('thousand', 32),
#  ('\\"the', 32),
#  ('taken', 32),
#  ('find', 32),
#  ('died', 32),
#  ('army', 32),
#  ('among', 31),
#  ('come', 31),
#  ('men,', 30),
#  ('about', 30),
#  ('castruccio,', 30),
#  ('concerning', 30),
#  ('seen', 30),
#  ('now', 30),
#  ('became', 29),
#  ('we', 29),
#  ('others,', 29),
#  ('once', 29),
#  ('--', 29),
#  ('reason', 29),
#  ('give', 29),
#  ('above', 29),
#  ('florence', 28),
#  ('entirely', 28),
#  ('states', 28),
#  ('see', 28),
#  ('her', 28),
#  ('given', 28),
#  ('power', 28),
#  ('secure', 28),
#  ('electronic', 27),
#  ('use', 27),
#  ('soldiers', 27),
#  ('held', 27),
#  ('chapter', 27),
#  ('works', 27),
#  ('country', 27),
#  ('alexander', 27),
#  ('said', 27),
#  ('let', 27),
#  ('know', 27),
#  ('italy', 26),
#  ('death', 26),
#  ('affairs', 26),
#  ('di', 26),
#  ('few', 26),
#  ('kept', 26),
#  ('born', 26),
#  ('say', 26),
#  ('old', 25),
#  ('and,', 25),
#  ('me', 25),
#  ('brought', 25),
#  ('people,', 25),
#  ('acquired', 25),
#  ('neither', 25),
#  ('put', 25),
#  ('left', 25),
#  ('this,', 25),
#  ('times', 24),
#  ('nothing', 24),
#  ('reputation', 24),
#  ('kingdom', 23),
#  ('better', 23),
#  ('war', 23),
#  ('favour', 23),
#  ('terms', 23),
#  ('one,', 23),
#  ('friends', 23),
#  ('part', 23),
#  ('state,', 23),
#  ('himself,', 23),
#  ('city', 23),
#  ('infantry', 22),
#  ('because,', 22),
#  ('armed', 22),
#  ('francesco', 22),
#  ('them;', 22),
#  ('called', 22),
#  ('wise', 22),
#  ('over', 22),
#  ('consider', 22),
#  ('difficulties', 22),
#  ('full', 22),
#  ('each', 22),
#  ('took', 22),
#  ('killed', 21),
#  ('opportunity', 21),
#  ('leave', 21),
#  ('away', 21),
#  ('set', 21),
#  ('gutenberg', 21),
#  ('soldiers,', 21),
#  ('unless', 21),
#  ('it.', 21),
#  ('rather', 21),
#  ('enemy', 21),
#  ('forces', 21),
#  ('bring', 20),
#  ('get', 20),
#  ('son', 20),
#  ('cause', 20),
#  ('house', 20),
#  ('citizens', 20),
#  ('still', 20),
#  ('hundred', 20),
#  ('ever', 20),
#  ('means', 20),
#  ('attack', 20),
#  ('accustomed', 20),
#  ('turned', 20),
#  ('gave', 20),
#  ('lost', 20),
#  ('less', 20),
#  ('life', 20),
#  ('family', 20),
#  ('except', 20),
#  ('principalities', 20),
#  ('private', 19),
#  ('lucca,', 19),
#  ('orsini', 19),
#  ('thou', 19),
#  ('received', 19),
#  ('follow', 19),
#  ('present', 19),
#  ('lucca', 19),
#  ('france', 19),
#  ('often', 19),
#  ('avoid', 19),
#  ('valour', 19),
#  ('help', 19),
#  ('went', 19),
#  ('between', 19),
#  ('princes,', 19),
#  ('actions', 19),
#  ('seeing', 18),
#  ('towards', 18),
#  ('san', 18),
#  ('whole', 18),
#  ('caused', 18),
#  ('florentine', 18),
#  ('defend', 18),
#  ('italy,', 18),
#  ('course', 18),
#  ('themselves,', 18),
#  ('us', 18),
#  ('same', 18),
#  ('france,', 18),
#  ('foundation', 18),
#  ('pagolo', 18),
#  ('nevertheless', 18),
#  ('cavalry', 18),
#  ('mind', 17),
#  ('compelled', 17),
#  ('wishing', 17),
#  ('down', 17),
#  ('reached', 17),
#  ('man,', 17),
#  ('hated', 17),
#  ('soon', 17),
#  ('da', 17),
#  ('like', 17),
#  ('need', 17),
#  ('literary', 17),
#  ('arms,', 17),
#  ('ruin', 17),
#  ('whether', 17),
#  ('done', 17),
#  ('easily', 17),
#  ('hands', 17),
#  ('roman', 16),
#  ('former', 16),
#  ('god', 16),
#  ('driven', 16),
#  ('you,', 16),
#  ('giovanni', 16),
#  ('pisa,', 16),
#  ('until', 16),
#  ('already', 16),
#  ('rome', 16),
#  ('gain', 16),
#  ('far', 16),
#  ('end', 16),
#  ('united', 16),
#  ('short', 16),
#  ('too', 16),
#  ('person', 16),
#  ('case', 16),
#  ('live', 16),
#  ('show', 16),
#  ('during', 16),
#  ('quickly', 16),
#  ('anything', 16),
#  ('said,', 16),
#  ('him;', 16),
#  ('raised', 16),
#  ('ability', 16),
#  ('second', 16),
#  ('laws', 16),
#  ('appear', 16),
#  ('especially', 16),
#  ('here', 16),
#  ('greater', 15),
#  ('saw', 15),
#  ('knew', 15),
#  ('fortune,', 15),
#  ('owing', 15),
#  ('cesare', 15),
#  ('stand', 15),
#  ('attacked', 15),
#  ('rule', 15),
#  ('subject', 15),
#  ('church', 15),
#  ('place', 15),
#  ('hope', 15),
#  ('willing', 15),
#  ('assistance', 15),
#  ('war,', 15),
#  ('julius', 15),
#  ('appeared', 15),
#  ('happened', 15),
#  ('pass', 15),
#  ('so,', 15),
#  ('none', 14),
#  ('master', 14),
#  ('difficult', 14),
#  ('battle', 14),
#  ('send', 14),
#  ('powerful', 14),
#  ('french', 14),
#  ('reasons', 14),
#  ('within', 14),
#  ('nobles,', 14),
#  ('duke,', 14),
#  ('enemies', 14),
#  ('go', 14),
#  ('pisa', 14),
#  ('off', 14),
#  ('enough', 14),
#  ('four', 14),
#  ('donations', 14),
#  ('wished', 14),
#  ('you.', 14),
#  ('lose', 14),
#  ('italian', 14),
#  ('it;', 14),
#  ('public', 14),
#  ('hostile', 14),
#  ('nature', 14),
#  ('florentines,', 14),
#  ('subjects', 14),
#  ('oliverotto', 14),
#  ('difficulty', 14),
#  ('alexander,', 14),
#  ('greatest', 14),
#  ('years', 14),
#  ('understand', 13),
#  ('party', 13),
#  ('copyright', 13),
#  ('sufficient', 13),
#  ('louis', 13),
#  ('taking', 13),
#  ('five', 13),
#  ('methods', 13),
#  ('speak', 13),
#  ('laid', 13),
#  ('support', 13),
#  ('nicolo', 13),
#  ('empire', 13),
#  ('hand,', 13),
#  ('even', 13),
#  ('which,', 13),
#  ('nevertheless,', 13),
#  ('open', 13),
#  ('emperor', 13),
#  ('discuss', 13),
#  ('turn', 13),
#  ('aid', 13),
#  ('latter', 13),
#  ('position', 13),
#  ('heard', 13),
#  ('bad', 13),
#  ('archive', 13),
#  ('desire', 13),
#  ('beginning', 12),
#  ('remain', 12),
#  ('cities', 12),
#  ('side', 12),
#  ('rely', 12),
#  ('above,', 12),
#  ('told', 12),
#  ('feared', 12),
#  ('victory', 12),
#  ('florence,', 12),
#  ('time,', 12),
#  ('thought', 12),
#  ('everything', 12),
#  ('army,', 12),
#  ('free', 12),
#  ('government', 12),
#  ('following', 12),
#  ("machiavelli's", 12),
#  ('again', 12),
#  ('comes', 12),
#  ('arose', 12),
#  ('created', 12),
#  ('forced', 12),
#  ('he,', 12),
#  ('else', 12),
#  ('known', 12),
#  ('greatness', 12),
#  ('lord', 12),
#  ('others.', 12),
#  ('seized', 12),
#  ('days', 12),
#  ('river', 12),
#  ('hence', 12),
#  ('country,', 12),
#  ('decided', 12),
#  ('uguccione', 12),
#  ('subjects,', 12),
#  ('written', 12),
#  ('trouble', 12),
#  ('but,', 11),
#  ('number', 11),
#  ('charles', 11),
#  ('ready', 11),
#  ('thee', 11),
#  ('am', 11),
#  ('license', 11),
#  ('father', 11),
#  ('thing', 11),
#  ('longer', 11),
#  ('factions', 11),
#  ('foundations', 11),
#  ('occupied', 11),
#  ('romans', 11),
#  ('said:', 11),
#  ('outside', 11),
#  ('access', 11),
#  ('antonio', 11),
#  ('body', 11),
#  ('return', 11),
#  ('are,', 11),
#  ('just', 11),
#  ('destroyed', 11),
#  ('pistoia', 11),
#  ('according', 11),
#  ('maintain', 11),
#  ('venetians', 11),
#  ('city,', 11),
#  ('conduct', 11),
#  ('causes', 11),
#  ('rome,', 11),
#  ('forth', 11),
#  ('examples', 11),
#  ('agree', 11),
#  ('milan,', 11),
#  ('reproach', 11),
#  ('believe', 11),
#  ('paragraph', 11),
#  ('fight', 11),
#  ('ancient', 11),
#  ('easy', 11),
#  ('machiavelli,', 11),
#  ('character', 11),
#  ('friends,', 11),
#  ('hatred', 11),
#  ('keeping', 11),
#  ('fear,', 11),
#  ('injure', 11),
#  ('knowing', 10),
#  ('name', 10),
#  ('remained', 10),
#  ('matters', 10),
#  ('venetians,', 10),
#  ('knowledge', 10),
#  ('experience', 10),
#  ('orsini,', 10),
#  ('used', 10),
#  ('happens', 10),
#  ('seen,', 10),
#  ('ruled', 10),
#  ('milan', 10),
#  ('passed', 10),
#  ('overcome', 10),
#  ('year', 10),
#  ('impossible', 10),
#  ('sforza,', 10),
#  ('obtained', 10),
#  ('care', 10),
#  ('shown', 10),
#  ('other,', 10),
#  ('think', 10),
#  ('around', 10),
#  ('allowed', 10),
#  ('della', 10),
#  ('moved', 10),
#  ('agreement', 10),
#  ('principality,', 10),
#  ('military', 10),
#  ('rest', 10),
#  ('doing', 10),
#  ('near', 10),
#  ('drive', 10),
#  ('partly', 10),
#  ('quite', 10),
#  ('medici', 10),
#  ('affairs,', 10),
#  ('principality', 10),
#  ('authority', 10),
#  ('danger', 10),
#  ('enemy,', 10),
#  ('lucca.', 10),
#  ('began', 10),
#  ('property', 10),
#  ('pope,', 10),
#  ('word', 10),
#  ('certain', 10),
#  ('change', 10),
#  ('possession', 10),
#  ('stood', 10),
#  ('win', 9),
#  ('otherwise', 9),
#  ('hereditary', 9),
#  ('rules', 9),
#  ('states,', 9),
#  ('.', 9),
#  ('ways', 9),
#  ('strength', 9),
#  ('hast', 9),
#  ('honour', 9),
#  ('assist', 9),
#  ('things,', 9),
#  ('head', 9),
#  ('loved', 9),
#  ('third', 9),
#  ('form', 9),
#  ('pistoia,', 9),
#  ('vitelli,', 9),
#  ('captains', 9),
#  ('read', 9),
#  ('years,', 9),
#  ('memory', 9),
#  ('prepared', 9),
#  ('guinigi', 9),
#  ('followed', 9),
#  ('again,', 9),
#  ('general', 9),
#  ('peace', 9),
#  ('towns', 9),
#  ('sinigalia,', 9),
#  ('yield', 9),
#  ('liberality', 9),
#  ('follows', 9),
#  ('whose', 9),
#  ('italy.', 9),
#  ('mercenaries,', 9),
#  ('recognize', 9),
#  ('day', 9),
#  ('giving', 9),
#  ('ten', 9),
#  ('tuscany,', 9),
#  ('friendly', 9),
#  ('whenever', 9),
#  ('asked', 9),
#  ('opinion', 9),
#  ('thy', 9),
#  ('obedience', 9),
#  ('forward', 9),
#  ('gained', 9),
#  ('people;', 9),
#  ('making', 9),
#  ('people.', 9),
#  ('learn', 9),
#  ('guelph', 9),
#  ('entered', 9),
#  ('fail', 9),
#  ('matter', 9),
#  ('charge', 9),
#  ('succeeded', 9),
#  ('power,', 9),
#  ('force', 9),
#  ('saying', 9),
#  ('amongst', 8),
#  ('lived', 8),
#  ('right', 8),
#  ('including', 8),
#  ('state.', 8),
#  ('captain', 8),
#  ('uguccione,', 8),
#  ('fighting', 8),
#  ('discussed', 8),
#  ('nobles', 8),
#  ('tax', 8),
#  ('true', 8),
#  ('deeds', 8),
#  ('returned', 8),
#  ('authority,', 8),
#  ('armies', 8),
#  ('arms.', 8),
#  ('back', 8),
#  ('fee', 8),
#  ('conquered', 8),
#  ('cardinal', 8),
#  ('seize', 8),
#  ('fall', 8),
#  ('someone', 8),
#  ('believed', 8),
#  ('prince\\', 8),
#  ('three', 8),
#  ('beyond', 8),
#  ('example', 8),
#  ('high', 8),
#  ('money', 8),
#  ('wisdom', 8),
#  ('receive', 8),
#  ('common', 8),
#  ('almost', 8),
#  ('oppressed', 8),
#  ('naples,', 8),
#  ('unable', 8),
#  ('ambition', 8),
#  ('domain', 8),
#  ('elected', 8),
#  ('destroy', 8),
#  ('vitelli', 8),
#  ('provided', 8),
#  ('resist', 8),
#  ('bound', 8),
#  ('faith', 8),
#  ('observed', 8),
#  ('rise', 8),
#  ('look', 8),
#  ('proper', 8),
#  ('enterprises', 8),
#  ('courage', 8),
#  ('expect', 8),
#  ('provide', 8),
#  ('lombardy,', 8),
#  ('act', 8),
#  ('wishes', 8),
#  ('up,', 8),
#  ('obtain', 8),
#  ('friend', 8),
#  ('becomes', 8),
#  ('established', 8),
#  ('work,', 8),
#  ('becoming', 8),
#  ('please', 8),
#  ('account', 8),
#  ('prudent', 8),
#  ('makes', 7),
#  ('met', 7),
#  ('count', 7),
#  ('meet', 7),
#  ('last', 7),
#  ('stefano', 7),
#  ('great,', 7),
#  ('recall', 7),
#  ('good,', 7),
#  ('content', 7),
#  ('using', 7),
#  ('section', 7),
#  ('do,', 7),
#  ('exercise', 7),
#  ('myself', 7),
#  ('drew', 7),
#  ('poor', 7),
#  ('cruelty,', 7),
#  ('further', 7),
#  ('different', 7),
#  ('others;', 7),
#  ('posted', 7),
#  ('valiant', 7),
#  ('conquered,', 7),
#  ('opposite', 7),
#  ('conquer', 7),
#  ('prince.', 7),
#  ('command', 7),
#  ('reasons,', 7),
#  ('recent', 7),
#  ('information', 7),
#  ('offend', 7),
#  ('natural', 7),
#  ('whereupon', 7),
#  ('words', 7),
#  ('speaking', 7),
#  ('refund', 7),
#  ('necessity', 7),
#  ('sinigalia', 7),
#  ('further,', 7),
#  ('enemy.', 7),
#  ('fortresses', 7),
#  ('thus,', 7),
#  ('inclined', 7),
#  ('benefits', 7),
#  ('ruined', 7),
#  ('important', 7),
#  ('themselves.', 7),
#  ('permission', 7),
#  ('youth', 7),
#  ('afterwards,', 7),
#  ('il', 7),
#  ('reasonable', 7),
#  ('when,', 7),
#  ('greece,', 7),
#  ('lords', 7),
#  ('vitellozzo', 7),
#  ('new,', 7),
#  ('kind', 7),
#  ('opportunity,', 7),
#  ('cruelty', 7),
#  ('permitted', 7),
#  ('various', 7),
#  ('arise', 7),
#  ('carry', 7),
#  ('governed', 7),
#  ('human', 7),
#  ('ease', 7),
#  ('him:', 7),
#  ('copy', 7),
#  ('divided', 7),
#  ('since', 7),
#  ('satisfy', 7),
#  ('maintained', 7),
#  ('intended', 7),
#  ('lombardy', 7),
#  ('notwithstanding', 7),
#  ('-', 7),
#  ('virtue', 7),
#  ('appearing', 7),
#  ('inasmuch', 7),
#  ('copies', 7),
#  ('world', 7),
#  ('strong', 7),
#  ('powers', 7),
#  ('romagna', 7),
#  ('armies,', 7),
#  ('whereas', 7),
#  ('sufficiently', 7),
#  ('designs', 7),
#  ('arises', 7),
#  ('works.', 7),
#  ('advantageous', 7),
#  ('conspired', 7),
#  ('security', 7),
#  ('while', 7),
#  ('times,', 7),
#  ('castle', 7),
#  ('way,', 7),
#  ('future', 7),
#  ('utmost', 7),
#  ('large', 7),
#  ('ways,', 7),
#  ('associated', 7),
#  ('allow', 7),
#  ('assembled', 7),
#  ('truth', 7),
#  ('close', 7),
#  ('appointed', 7),
#  ('study', 7),
#  ('river,', 7),
#  ('paid', 7),
#  ('auxiliaries,', 7),
#  ('question', 7),
#  ('remains', 7),
#  ('best', 7),
#  ('turk', 7),
#  ('small', 7),
#  ('friends.', 7),
#  ('oliverotto,', 7),
#  ('appears', 7),
#  ('jacopo', 6),
#  ('say,', 6),
#  ("one's", 6),
#  ('goodwill', 6),
#  ('for,', 6),
#  ('obey', 6),
#  ('parties', 6),
#  ('men.', 6),
#  ('loss', 6),
#  ('prince,\\', 6),
#  ('horsemen', 6),
#  ('observe', 6),
#  ('leaving', 6),
#  ('forget', 6),
#  ('distribute', 6),
#  ('distribution', 6),
#  ('exiled', 6),
#  ('quiet', 6),
#  ('agreement,', 6),
#  ("de'", 6),
#  ('mountains', 6),
#  ('liberal,', 6),
#  ('forces,', 6),
#  ('govern', 6),
#  ('distrusted', 6),
#  ('showing', 6),
#  ('king,', 6),
#  ('greece', 6),
#  ('title', 6),
#  ('emperors', 6),
#  ('answered', 6),
#  ('romagna,', 6),
#  ('acquiring', 6),
#  ('not,', 6),
#  ('official', 6),
#  ('qualities', 6),
#  ('considered,', 6),
#  ('pagolo,', 6),
#  ('comply', 6),
#  ('placed', 6),
#  ('led', 6),
#  ('web', 6),
#  ('mercenaries', 6),
#  ('distant', 6),
#  ('fortunes', 6),
#  ('orders', 6),
#  ('(+)', 6),
#  ('life,', 6),
#  ('capable', 6),
#  ('distributing', 6),
#  ('enterprise', 6),
#  ('necessary,', 6),
#  ('measure', 6),
#  ('point', 6),
#  ('contrary', 6),
#  ('finding', 6),
#  ('fermo,', 6),
#  ('horsemen,', 6),
#  ('leads', 6),
#  ('naples', 6),
#  ('senate', 6),
#  ('esteemed', 6),
#  ('writing', 6),
#  ('whoever', 6),
#  ('renown', 6),
#  ('if,', 6),
#  ('citizens,', 6),
#  ('civil', 6),
#  ('young', 6),
#  ('unarmed', 6),
#  ('coming', 6),
#  ('degree', 6),
#  ('foot', 6),
#  ('art', 6),
#  ('twenty', 6),
#  ('hand', 6),
#  ('fought', 6),
#  ('work.', 6),
#  ('enemies,', 6),
#  ('prince.\\', 6),
#  ('why', 6),
#  ('sought', 6),
#  ('states.', 6),
#  ('circumstances', 6),
#  ('several', 6),
#  ('bologna,', 6),
#  ('works,', 6),
#  ('rebellion', 6),
#  ('got', 6),
#  ('desired', 6),
#  ('glory', 6),
#  ('medici,', 6),
#  ('secret', 6),
#  ('everything,', 6),
#  ('liberty', 6),
#  ('governor', 6),
#  ('phrase', 6),
#  ('to,', 6),
#  ('depend', 6),
#  ('giorgio', 6),
#  ('holding', 6),
#  ('spain', 6),
#  ('office', 6),
#  ('excelled', 6),
#  ('foreigners', 6),
#  ("castruccio's", 6),
#  ('ability,', 6),
#  ('offer', 6),
#  ('night', 6),
#  ('popular', 6),
#  ('recourse', 6),
#  ('temporal', 6),
#  ('excuse', 6),
#  ('illustrious', 6),
#  ('excellent', 6),
#  ('giuliano', 6),
#  ('action', 6),
#  ('defended', 6),
#  ('takes', 6),
#  ('defect', 6),
#  ('volunteers', 6),
#  ('is,', 6),
#  ('retain', 6),
#  ('alone,', 6),
#  ('fell', 6),
#  ('state;', 6),
#  ('republic,', 6),
#  ('ii', 6),
#  ('extraordinary', 6),
#  ('similar', 6),
#  ('changes', 6),
#  ('possible', 6),
#  ('side,', 6),
#  ('country.', 6),
#  ('church,', 6),
#  ('romans,', 6),
#  ('deceive', 6),
#  ('citizen', 6),
#  ('there.', 6),
#  ('least', 6),
#  ('individual', 6),
#  ('render', 6),
#  ('lay', 6),
#  ('otherwise,', 6),
#  ('chance', 6),
#  ('advantage', 6),
#  ('out,', 6),
#  ('modern', 6),
#  ('borgia', 5),
#  ('faithful,', 5),
#  ('ebook', 5),
#  ('attributed', 5),
#  ('dominions', 5),
#  ('alone', 5),
#  ('answered:', 5),
#  ('accepted', 5),
#  ('save', 5),
#  ('carried', 5),
#  ...]

# %%
# %cat jobs/script_000061748.py.err
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# creating tmp directory /tmp/script_000061748.root.20151013.134037.866821
# writing to /tmp/script_000061748.root.20151013.134037.866821/step-0-mapper_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /tmp/script_000061748.root.20151013.134037.866821/step-0-mapper-sorted
# > sort /tmp/script_000061748.root.20151013.134037.866821/step-0-mapper_part-00000
# writing to /tmp/script_000061748.root.20151013.134037.866821/step-0-reducer_part-00000
# Counters from step 1:
#   (no counters found)
# Moving /tmp/script_000061748.root.20151013.134037.866821/step-0-reducer_part-00000 -> /tmp/script_000061748.root.20151013.134037.866821/output/part-00000
# Streaming final output from /tmp/script_000061748.root.20151013.134037.866821/output
# removing tmp directory /tmp/script_000061748.root.20151013.134037.866821

# %% [markdown]
# Executing on the existing Hadoop cluster

# %%
# %%mapreduce $myfile hadoop
#
# def mapper(self, _, line):
#     pass
# def reducer(self, key, line):
#     pass

# %% [markdown]
# What if i want to modify directly the file?
#
# Can i use the extension without writing the file, but only executing my script with MrJob?

# %% [markdown]
# Yes

# %%
# Line execution, give a file you created or modified 
# %mapreduce $myfile jobs/script_000061748.py hadoop
# Out:
# Input file is: /data/worker/books/prince.txt
# File provided by user
# Executing Mrjob.
# Done!
#
# Files:
# jobs/script_000061748.py      jobs/script_000061748.py.out
# jobs/script_000061748.py.err
# {'': 2016,
#  'sight': 4,
#  'fight.': 1,
#  'worth': 1,
#  'continual': 2,
#  'excelled': 6,
#  '1513,': 2,
#  'gentleman.': 1,
#  'comes': 12,
#  'guido,': 1,
#  'extraordinary': 6,
#  'saddles': 1,
#  'arbiter,': 1,
#  'canzoni,': 1,
#  'discover': 4,
#  'enlarged': 1,
#  '1502;': 3,
#  '1457.': 1,
#  'almost': 8,
#  'enriching': 2,
#  'infant.': 1,
#  'cry': 4,
#  'inquiries': 1,
#  'fast.': 1,
#  'possente,': 2,
#  'sharp': 2,
#  'mere': 2,
#  'xenophon.': 1,
#  'cost,': 2,
#  '4': 1,
#  '252': 1,
#  'think': 10,
#  'free.': 2,
#  'scanty': 1,
#  'merciful': 2,
#  'reproached': 2,
#  'agreeable,': 1,
#  'ghibellines,': 2,
#  'council': 3,
#  'thirdly,': 1,
#  '1.c.': 1,
#  '\\"an': 2,
#  'he': 904,
#  'building.': 1,
#  'above-named': 4,
#  'bind': 5,
#  'croce.': 1,
#  'ready': 11,
#  'durable,': 1,
#  'now': 30,
#  'carnascialeschi.': 1,
#  'accepted,': 1,
#  'pitigliano;': 1,
#  'appearance': 1,
#  'state.': 8,
#  'sinigalia,': 9,
#  'different': 7,
#  'middle-aged': 1,
#  'affirm': 1,
#  'italian,': 1,
#  'future': 7,
#  'scruple': 1,
#  'past,': 1,
#  'settled,': 1,
#  'fruit': 1,
#  'correspondencies(*)': 1,
#  'business@pglaf.org.': 1,
#  'provided': 8,
#  'princes': 35,
#  'dispensed': 1,
#  'eat,\\': 1,
#  'conqueror.\\': 1,
#  'rebelled': 4,
#  'sparta,': 1,
#  'command.': 1,
#  'guelphs': 3,
#  'upright,': 2,
#  'astonished': 2,
#  'rovere,': 1,
#  'entrusting': 1,
#  'romulus,': 1,
#  'secrecy,': 1,
#  'movement': 1,
#  'allied': 2,
#  'outraged': 1,
#  'pisa,': 16,
#  'letting': 2,
#  'told': 12,
#  'acceptable': 1,
#  'confront': 1,
#  'blood': 1,
#  'hand;': 1,
#  'persisted': 1,
#  'settle': 3,
#  'dispossessed': 1,
#  '1502.': 1,
#  'neglected': 3,
#  'discourse,': 1,
#  'many,': 2,
#  'same.\\': 1,
#  'friends': 23,
#  'marched': 3,
#  '1.': 2,
#  'influenced': 2,
#  'that': 692,
#  'taking': 13,
#  'career:': 1,
#  'portion': 3,
#  'errors,': 2,
#  '6.': 1,
#  'xxv': 1,
#  'employees': 2,
#  'constitution': 2,
#  'women': 1,
#  'death': 26,
#  'glory': 6,
#  '\\"religione\\': 1,
#  'disloyal': 2,
#  'writer': 1,
#  'fees,': 1,
#  'chaste;': 1,
#  'must': 39,
#  'care': 10,
#  'court': 4,
#  'garrison': 2,
#  'on': 199,
#  'aid': 13,
#  'hast': 9,
#  '1.e.1': 3,
#  'g.': 1,
#  'maude': 1,
#  'preserving': 3,
#  'let': 27,
#  'fossombrone,': 1,
#  'senate': 6,
#  'action.': 1,
#  'hands.': 1,
#  'chase,': 1,
#  'subject': 15,
#  'trouble,': 2,
#  'staley': 1,
#  'singularly': 1,
#  'average': 2,
#  'attacked': 15,
#  'saturate': 1,
#  '1.f.': 1,
#  'precept': 2,
#  'continued': 5,
#  'magnifico.': 1,
#  'sister': 1,
#  'causing': 1,
#  'e.': 1,
#  'http://www.gutenberg.org': 1,
#  'o': 1,
#  'keeping': 11,
#  'soldiers;': 2,
#  'pagolo--whom': 1,
#  'majesty': 4,
#  'fort,': 1,
#  'resided': 3,
#  'old.': 1,
#  'abate': 1,
#  'directs': 1,
#  'well,': 3,
#  'blush': 1,
#  'more,': 4,
#  'seventeenth': 1,
#  'care.': 1,
#  'yours.': 1,
#  'finest': 1,
#  '1.e.9.': 3,
#  'doubtful,': 1,
#  'sister.': 1,
#  '\\"crudelta\\': 1,
#  'word.': 2,
#  '\\"right': 1,
#  'orsini,': 10,
#  'specified': 2,
#  'neapolitans': 1,
#  'andria,': 1,
#  'arrayed': 1,
#  'durable.': 1,
#  'occupy': 1,
#  'beaten,': 1,
#  'definiendis,': 1,
#  'deceives': 1,
#  'alternate': 1,
#  'his,': 1,
#  'worst': 1,
#  'timid': 1,
#  'prudence': 5,
#  'englishman': 2,
#  'contributes': 1,
#  'idle,': 1,
#  'pieces,': 1,
#  'scattered': 4,
#  'xx': 1,
#  'landriani,': 1,
#  '1905:': 1,
#  'them--two': 1,
#  'thank': 1,
#  'towns,': 1,
#  'oligarchy': 1,
#  'irresolute,': 1,
#  'loses,': 1,
#  'rejected': 2,
#  'timber': 1,
#  'ears': 1,
#  'annoyances.': 1,
#  'waits': 1,
#  'bed': 2,
#  'bolognese,': 1,
#  'wounds': 1,
#  'maintained.': 1,
#  'alberico': 1,
#  'seasoning': 1,
#  'terza': 2,
#  'instrumentality': 1,
#  'acceptable.': 1,
#  'eminence.': 1,
#  'maternal': 1,
#  'fight.\\': 1,
#  '(and': 2,
#  'narrowly': 1,
#  'labour': 1,
#  'physicians': 1,
#  'ruin.': 3,
#  'self-government;': 1,
#  'communicated': 1,
#  'bodily': 2,
#  'delinquents,': 1,
#  'mean-spirited,': 1,
#  'verb': 1,
#  'alessandria,': 1,
#  'agreement,': 6,
#  'prince,': 45,
#  'her.': 4,
#  'restored.': 1,
#  'envied': 1,
#  '1508': 1,
#  'lands,': 1,
#  'dei': 2,
#  'actual,': 1,
#  'hoping': 3,
#  'way.': 4,
#  'assistance': 15,
#  'minority': 1,
#  'such': 107,
#  'dominions.': 2,
#  'governorship': 1,
#  'understanding': 2,
#  '1512': 2,
#  'employment,': 1,
#  'silence.': 1,
#  'unwilling': 1,
#  '\\"clans\\': 1,
#  'hindrance,': 1,
#  'deceived,': 3,
#  'solely': 3,
#  'surrendered,': 2,
#  'conceals': 1,
#  'reasons,': 7,
#  'say,': 6,
#  'bad,': 3,
#  'spoils,': 1,
#  'throne,': 1,
#  'watched,': 1,
#  'withstand': 4,
#  'thereupon': 2,
#  'exalted': 1,
#  'efforts': 2,
#  'address': 2,
#  'security,': 3,
#  'liking.': 1,
#  'supporting': 1,
#  'shortly': 3,
#  'own);': 1,
#  'mercy,': 4,
#  'small': 7,
#  'fortifying': 1,
#  'exemplar': 2,
#  'winning,': 1,
#  'iv': 1,
#  'states.': 6,
#  'others),': 1,
#  'upside': 1,
#  'hazard.': 1,
#  'cogunt': 1,
#  'answer:': 1,
#  'absorbed': 1,
#  'craft': 2,
#  'genoa': 1,
#  'out': 71,
#  'ordinances': 4,
#  'inganni': 1,
#  'boldness': 2,
#  'punishing': 1,
#  'naples;': 1,
#  'appear.': 1,
#  'unexpectedly': 1,
#  'greatness.': 2,
#  'choice': 3,
#  'doubt': 5,
#  'honour,': 2,
#  'truth': 7,
#  'sack,': 1,
#  'dangers,': 2,
#  'bergamo,': 1,
#  'italia.\\"--': 1,
#  'unless': 21,
#  'asiatic': 1,
#  'besieged': 2,
#  'observation': 1,
#  'assured,': 2,
#  'endured,': 1,
#  'prosecution': 1,
#  'signa,': 1,
#  'fidelity': 5,
#  'equipment': 1,
#  'infringement,': 1,
#  'vitelli,': 9,
#  'clemency,': 1,
#  'observing': 3,
#  'pressed': 1,
#  'overturn': 1,
#  'both,': 5,
#  'predominancy': 1,
#  'help': 19,
#  'master': 14,
#  'supreme,': 1,
#  'their': 266,
#  'spring': 1,
#  'service,': 1,
#  'cooled,': 1,
#  'nabis,': 1,
#  'envoys': 3,
#  '1232.txt': 1,
#  'goodness': 1,
#  'child.': 1,
#  'bearing': 3,
#  'dignity': 4,
#  'energy': 2,
#  'forli,': 1,
#  'banner': 1,
#  'viewing,': 1,
#  'aragon,': 2,
#  'action,': 4,
#  'becomes': 8,
#  'holder': 1,
#  'carlo,': 3,
#  'per': 2,
#  'green,': 1,
#  'tactics': 1,
#  'there,': 5,
#  'beginning,': 1,
#  'interesting,': 1,
#  '\\"rome': 2,
#  'able': 52,
#  'pious': 1,
#  'damages': 2,
#  'editions.': 1,
#  'sinigalia': 7,
#  'judgments': 1,
#  'lake': 1,
#  'us': 18,
#  'chances.': 1,
#  'another': 34,
#  'expanded,': 1,
#  'banished': 1,
#  'benefit': 1,
#  'get,': 1,
#  'principalities.': 2,
#  'silence,': 1,
#  'friendship': 4,
#  'burnt,': 1,
#  'concerning': 30,
#  'polishing': 1,
#  'tueri.\\"(*)': 1,
#  'frivolous,': 1,
#  'god,': 2,
#  'whether,': 1,
#  'relies': 1,
#  'obedient,': 1,
#  'proof': 3,
#  'answered': 6,
#  'excess': 1,
#  'ruining': 1,
#  'allowed': 10,
#  'period;': 1,
#  'been,': 3,
#  'duo': 1,
#  'over,': 1,
#  "cicero's": 1,
#  'comments': 1,
#  'circles,': 1,
#  'goodness,': 1,
#  'training,': 1,
#  'credit': 4,
#  'nel': 1,
#  'leader': 3,
#  '\\"project': 5,
#  'conscious': 1,
#  'laws': 16,
#  'forces': 21,
#  'torn,': 1,
#  'signs': 1,
#  'luck': 2,
#  'little,': 2,
#  'number': 11,
#  'waited': 2,
#  'prosperous': 1,
#  'cured,': 1,
#  'link': 1,
#  'shortest': 1,
#  'individual;': 1,
#  'bears': 2,
#  'sad': 1,
#  'terrify': 3,
#  'sloth': 1,
#  'treacheries': 1,
#  'captive.': 1,
#  'sons': 4,
#  'goodwill,': 3,
#  'albinus': 3,
#  'necessities,': 1,
#  'despoiled,': 2,
#  'honourably': 2,
#  'cenami,': 1,
#  'unexpectedly,': 1,
#  'lazerone': 1,
#  'forth': 11,
#  'speak': 13,
#  'measured': 3,
#  'flatterers': 2,
#  'family': 20,
#  'orsini': 19,
#  'decertandi,': 1,
#  'forsook': 1,
#  'gallantly': 1,
#  'void': 2,
#  'districts': 1,
#  'street': 2,
#  'hears': 1,
#  'outrageous': 1,
#  'rouen,': 1,
#  'goest': 2,
#  'avarice': 1,
#  'rode': 3,
#  'inwardly': 1,
#  'bones': 1,
#  'bit': 2,
#  'main': 2,
#  'permanent': 2,
#  'give,': 1,
#  'bow-shot,': 1,
#  'departure': 2,
#  'find': 32,
#  'good.': 1,
#  'xxi': 1,
#  'living': 3,
#  'provoked': 1,
#  'final': 1,
#  'arbitrament': 1,
#  'resided,': 1,
#  'religion,': 2,
#  'ways.': 3,
#  'wherein,': 1,
#  'silvestri,': 1,
#  'difficulties;': 1,
#  'liberty': 6,
#  'scipio;': 1,
#  'nothing': 24,
#  'anyone': 3,
#  'lord': 12,
#  'house.': 2,
#  'unguarded,': 1,
#  'limited': 5,
#  'merciful,': 2,
#  'violence,': 4,
#  'concluded': 3,
#  'swamp': 1,
#  'mercy': 2,
#  "people's": 1,
#  'vice': 1,
#  'desist': 1,
#  'exterminating': 1,
#  'length': 3,
#  'records,': 1,
#  'hand.': 1,
#  'fever,': 3,
#  'royalties': 1,
#  'anne': 1,
#  'disguise': 1,
#  'so': 195,
#  'witty': 1,
#  "alexander's": 1,
#  'aspire': 3,
#  'alliances,': 1,
#  'lively': 1,
#  'speak,': 3,
#  'fewer': 2,
#  'conqueror,': 2,
#  'bodies': 2,
#  'haste': 1,
#  'x.': 1,
#  'ii,': 1,
#  'listen': 4,
#  'supporters.': 1,
#  'expend': 1,
#  'fears,': 1,
#  'florentines;': 2,
#  'solemn': 1,
#  'dependent': 1,
#  'longer.': 3,
#  'canestrini,': 1,
#  'sins': 3,
#  'disputes': 1,
#  'strong': 7,
#  'writes': 2,
#  'advisable': 2,
#  'conspiracy;': 1,
#  'negotiate': 3,
#  'towards': 18,
#  'vitellian': 1,
#  'edition,': 1,
#  'ride': 1,
#  'giovanni,': 1,
#  '1.e.8': 2,
#  'flank': 1,
#  'examined,': 1,
#  'nicolo': 13,
#  'call': 3,
#  'sforza(*)': 1,
#  'rises': 2,
#  'like.': 1,
#  'suggest': 1,
#  'unquam': 1,
#  'disorder': 1,
#  'dismantled': 1,
#  'threatened,': 1,
#  'prosperity': 1,
#  'practise': 2,
#  'self-complacent': 1,
#  'qualifications,': 1,
#  'laid': 13,
#  'art': 6,
#  'ebook': 5,
#  'religion.': 1,
#  'both.': 2,
#  'energy,': 3,
#  'cap': 1,
#  'information': 7,
#  'require': 2,
#  'particular': 5,
#  'died': 32,
#  'collection': 4,
#  'girl': 1,
#  'tuscany,': 9,
#  'view': 2,
#  'engage': 1,
#  'intentions;': 1,
#  'besieging': 2,
#  'indemnify': 1,
#  'principality;': 4,
#  'victor': 2,
#  'unnecessary': 1,
#  'said:': 11,
#  'possesses': 1,
#  'me': 25,
#  'widow': 2,
#  'antiquity;': 1,
#  'ready;': 1,
#  'warranty': 1,
#  'dinner,': 1,
#  'behalf,': 1,
#  'loved,': 2,
#  'deity.': 1,
#  'any)': 1,
#  'badly': 2,
#  '1843,': 1,
#  'happen,': 3,
#  'moderated': 1,
#  'doubtful': 5,
#  'information:': 1,
#  'god.': 1,
#  'revenge,': 1,
#  'razed': 1,
#  'entirely': 28,
#  'easily': 17,
#  'downright': 1,
#  'goals': 1,
#  'chances': 2,
#  'interests': 1,
#  'pushed': 1,
#  'counteract': 1,
#  'mary,': 1,
#  'example;': 1,
#  'bondmen,': 1,
#  'seeing': 18,
#  'upon,': 2,
#  'holder),': 1,
#  'once': 29,
#  'degli': 2,
#  'efficient': 1,
#  'hatred;': 1,
#  'also.\\': 1,
#  'since,': 1,
#  'sixtus,': 1,
#  'forli\\': 1,
#  'perils': 1,
#  'securing': 1,
#  'varies': 1,
#  'hart,': 1,
#  'changed': 2,
#  'peretola,': 1,
#  'inevitably': 1,
#  'originator': 1,
#  'made;': 2,
#  'cowardice': 3,
#  'incautious': 1,
#  'intrigue': 1,
#  'abolished': 2,
#  'absolute': 3,
#  'rests': 1,
#  'violence.': 1,
#  'poverty': 2,
#  'desire': 13,
#  'new': 66,
#  'scarcely': 4,
#  'using': 7,
#  'pains': 1,
#  'commenting': 1,
#  'in:': 1,
#  'promoting': 2,
#  'dido,': 1,
#  'roots': 2,
#  'evidence': 3,
#  'naturally': 3,
#  'vicissitudes': 1,
#  "son's": 1,
#  'ordinary': 2,
#  'vi.': 2,
#  'introduce': 2,
#  '(methuen,': 1,
#  '1462,': 1,
#  'license': 11,
#  'soil': 1,
#  'fitness': 1,
#  'they': 437,
#  'hated;': 1,
#  'go': 14,
#  'calling': 1,
#  'emperor;': 1,
#  'composite,': 2,
#  'discourses,': 2,
#  'monsignor': 1,
#  'signification': 1,
#  'flanks,': 3,
#  'burgundy,': 1,
#  'vincula,': 2,
#  'ornaments': 1,
#  'duke.': 4,
#  'task,': 1,
#  '1328,': 2,
#  'aetolians;': 1,
#  'hence,': 1,
#  'favouring': 3,
#  'testify': 1,
#  'defeat,': 2,
#  'filling': 1,
#  'administration': 2,
#  'rout': 1,
#  'wearing': 1,
#  'resolution': 1,
#  'noticeable': 1,
#  'following': 12,
#  'tyrannical': 1,
#  'roman': 16,
#  'murdering': 1,
#  'crossed': 1,
#  'reported': 2,
#  'warranty,': 1,
#  'account': 8,
#  'rising': 2,
#  'build': 3,
#  'intervention.': 1,
#  'goliath,': 1,
#  'germans': 3,
#  'scali.': 1,
#  'taranto.': 1,
#  'red,': 1,
#  'electronically': 1,
#  'hiero,': 1,
#  'overwhelmed': 1,
#  'barbarous': 3,
#  'keeping.': 1,
#  'leo,': 1,
#  'fogliani': 2,
#  'appropriate': 1,
#  'speaking': 7,
#  'characteristic': 1,
#  'kept,': 1,
#  'baby': 1,
#  'accord': 1,
#  'dura,': 1,
#  'life-work': 1,
#  'tributary': 2,
#  '1.e.1.': 2,
#  'deviated': 1,
#  'phrases,': 1,
#  'ditches': 1,
#  'said.\\': 1,
#  'persons.': 1,
#  'faith,\\': 1,
#  'mr': 5,
#  'regions,': 1,
#  'remedies': 2,
#  'approach,': 1,
#  'macrinus,': 2,
#  'bloody': 1,
#  'fucecchio,': 2,
#  'liberality.': 2,
#  'viii': 3,
#  'looking': 2,
#  'furnished': 1,
#  '1409.': 1,
#  'liberality;': 1,
#  'methods': 13,
#  'prevail.': 1,
#  'mixed,': 1,
#  'bloodshed,': 1,
#  'royal': 1,
#  'days,': 2,
#  'france;': 3,
#  'offices': 1,
#  'files': 2,
#  'hoped': 5,
#  'matters': 10,
#  'duke': 67,
#  'ease': 7,
#  'war': 23,
#  'before': 41,
#  'therefore': 34,
#  'meaning,': 1,
#  'full,': 1,
#  'large': 7,
#  'ceased': 1,
#  'example,': 4,
#  'reward,': 1,
#  'advantage': 6,
#  'dissolution': 2,
#  'day': 9,
#  'fixed': 5,
#  'sequel': 1,
#  'tutor': 2,
#  'acuto.': 1,
#  'medes,': 1,
#  'danaro,': 1,
#  'families': 5,
#  'uncertain': 2,
#  'language,': 3,
#  "gutenberg-tm's": 1,
#  'paragraph': 11,
#  'asperity': 1,
#  'portentous.': 1,
#  'dressed': 1,
#  'eleventh,(+)': 1,
#  'signify': 1,
#  'rest.': 2,
#  'unless,': 1,
#  'steps': 2,
#  'changeful': 1,
#  'offence.\\': 1,
#  'barbarity.': 1,
#  'thirty-one': 1,
#  '(ad': 1,
#  'highly': 4,
#  'annibale': 2,
#  'ad': 4,
#  'misled': 1,
#  'meets': 1,
#  'understands': 2,
#  'integrity;': 1,
#  'seized': 12,
#  'consistent': 2,
#  'encampment': 1,
#  'refuge.': 1,
#  'satisfied.': 1,
#  'endured': 2,
#  '5th': 1,
#  'camp': 3,
#  'proclaimed': 1,
#  'correct;': 1,
#  'assistance.': 4,
#  'chose': 1,
#  'alone': 5,
#  'testimony': 2,
#  'allied,': 1,
#  'conduce': 1,
#  'telling': 1,
#  'lands': 1,
#  'rank,': 3,
#  'prove,': 1,
#  'disadvantageous;': 1,
#  'implied': 1,
#  'dust': 1,
#  'oppose': 4,
#  'valour': 19,
#  'turks': 1,
#  'finish': 1,
#  'character.': 2,
#  'attacking': 2,
#  'wives': 2,
#  'dangers': 5,
#  'enables': 2,
#  'strongest.': 1,
#  'admits': 1,
#  'immediately': 5,
#  'arises:': 1,
#  'horseback,': 2,
#  'endow': 1,
#  'unhappy': 1,
#  '50': 1,
#  'clearly': 2,
#  'avoid,': 1,
#  '9': 1,
#  'completed': 1,
#  'acceptable,': 1,
#  'debate': 1,
#  'oppress': 1,
#  'distance,': 1,
#  'purpose': 2,
#  'unhappily': 1,
#  'conditions': 4,
#  'glass': 1,
#  'defective': 2,
#  'treachery': 1,
#  'door,': 1,
#  'bold.': 1,
#  'pisans': 3,
#  'vitellozo,': 1,
#  'river.': 2,
#  '\\"faith,\\': 1,
#  'offers,': 1,
#  'vii': 2,
#  'everybody': 2,
#  'taxes.': 1,
#  'cannot,': 1,
#  'enemy,': 10,
#  'reads': 1,
#  'solemnly': 1,
#  'duke;': 3,
#  '\\"striving': 1,
#  '\\"florentine': 1,
#  'gusciana': 1,
#  'inflicted': 2,
#  'midst': 3,
#  'risen,': 1,
#  'vulgar': 1,
#  'distrust': 2,
#  'thousand': 32,
#  'mankind': 1,
#  'possession.': 1,
#  'incur': 1,
#  'prince.': 7,
#  'principles': 3,
#  'changes.': 1,
#  'france.': 3,
#  'weight': 2,
#  'accumulate': 1,
#  'sharing': 2,
#  'arrive,': 1,
#  'allow': 7,
#  'defend': 18,
#  'presumptuous': 2,
#  'arrest': 1,
#  'truth,': 3,
#  'alexander,': 14,
#  'simple,': 1,
#  'writers': 2,
#  'matteo': 4,
#  'one--the': 1,
#  'friendship,': 1,
#  'gross': 1,
#  '[his': 1,
#  'long': 36,
#  'surmount': 1,
#  'unjudged;': 1,
#  'custom': 2,
#  'marriage.': 1,
#  'choosing': 4,
#  'placed,': 1,
#  'alexander.': 1,
#  'history': 3,
#  'serravalle': 2,
#  'obeisance,': 1,
#  'partridge,': 1,
#  'frederick': 3,
#  'adds': 2,
#  '(if': 1,
#  'milan,': 11,
#  'giorgio,': 1,
#  'citizen': 6,
#  'throne': 2,
#  'consisted': 1,
#  'banquet': 3,
#  'pliant,': 1,
#  'gift': 3,
#  'pass': 15,
#  'quarters,': 4,
#  'affection': 1,
#  'dante': 1,
#  'unheard': 1,
#  'troops': 3,
#  'resist.': 1,
#  'known': 12,
#  'connection': 2,
#  'rained': 2,
#  'wisdom,': 1,
#  'literal': 1,
#  'divided': 7,
#  'freely,': 1,
#  'libro': 1,
#  'maximinus': 2,
#  'revenues': 1,
#  'succeeds': 1,
#  'sentence': 1,
#  'addition': 1,
#  'banishment': 1,
#  'promise': 1,
#  'confer': 3,
#  'assault': 1,
#  'addresses.': 1,
#  'short-sighted': 1,
#  'maximilian,(*)': 1,
#  'else': 12,
#  'himself;': 1,
#  'ascii\\': 2,
#  'adherents': 4,
#  'cruel,': 2,
#  'interfered': 1,
#  'bragged': 1,
#  'considerable': 2,
#  'undoes': 1,
#  'reader,': 1,
#  'donations': 14,
#  'firmly': 1,
#  'december,': 1,
#  'concerned.': 1,
#  '1448.': 1,
#  'especially': 16,
#  'remarkable': 5,
#  'panciatichi': 1,
#  'stripped': 1,
#  'desiring': 2,
#  'steep,': 1,
#  'behave': 1,
#  'principe,\\': 2,
#  'examples--one': 1,
#  'numantia,': 1,
#  'lovingly': 1,
#  'stands': 1,
#  'bank': 3,
#  'world.': 1,
#  'themselves.': 7,
#  'fidelity,(*)': 1,
#  'powers.': 1,
#  'true,\\': 1,
#  '1525.': 2,
#  'called,': 2,
#  'love': 5,
#  'position;': 1,
#  'gate': 5,
#  'magistracy,': 1,
#  'attracted': 1,
#  'attach': 2,
#  'fell': 6,
#  'day;': 3,
#  'consider,': 1,
#  'force': 9,
#  'disunited': 1,
#  'web': 6,
#  'miles,': 1,
#  'lanfranchi': 1,
#  'declaring': 1,
#  'further': 7,
#  'behind': 2,
#  'cesena': 2,
#  'fourthly,': 1,
#  'oliverotto;': 1,
#  'scali(+)': 1,
#  'free': 12,
#  'least': 6,
#  'groups,': 1,
#  'enraged': 1,
#  'calm': 1,
#  'georges': 1,
#  'defences': 2,
#  'estimate': 1,
#  'fighting;': 1,
#  ...}

# %% [markdown]
# ## More than a single step

# %% [markdown]
# mrjob can be configured to run different steps
#
# for each step you can specify which part has to be executed
# and the method to use within the class you wrote

# %%
def steps(self):
    return [
        MRStep(
            mapper=self.mapper_get_words,
            combiner=self.combiner_count_words,
            reducer=self.reducer_count_words),
        MRStep(reducer=self.reducer_find_max_word)
    ]

# %% [markdown]
# This could be an improvement for our mrjob extension:
#
# - if steps method is provided, override the default written by the extension

# %% [markdown]
# A quick note
#
# * With MrJob you cannot connect to a **remote** Hadoop cluster.
#     - Hadoop does not allow job submissions (class or executables) from outside.
# * On the contrary EMR on Amazon can be accessible from your laptop.
#     - Amazon created the [boto api](http://boto.readthedocs.org/en/latest/ref/emr.html) to solve the issue.

# %% [markdown]
# # Recap with Mrjob

# %% [markdown]
# You should really read the [documentation of the latest version](http://mrjob.readthedocs.org/en/latest/).
#
# It covers every need without getting too much complicated.
# There are many other options and advanced behaviours to discover.
#
# <small>
# Note 1: We are using the most recent version (*release* **v.0.5.0dev** ) because its the first one to support Python 3.
#
# Note 2: Developer are there to help you, see my case in https://github.com/Yelp/mrjob/issues/1142
# </small>

# %% [markdown]
# * More documentation than any other framework or library
# * Write code in a single class (per Hadoop job)
#     * Map and Reduce are single methods
#     * Very clean and simple
# * Advanced configuration
#     * Configure multiple steps
#     * Handle command line options inside the python code (see docs)
# * Easily wrap input/output
#     * No data copy required with HDFS
# * Hadoop logs or errors directly into the script output
# * **Switch environment without changing the code...!**

# %% [markdown]
# **Cons**
#
# * Doesn’t give you the same level of access to Hadoop APIs
#     - Better: Dumbo and Pydoop
#     - Other libraries can be faster if you use typedbytes

# %% [markdown]
# ### Comparison
# <img src='http://blog.cloudera.com/wp-content/uploads/2013/01/features.png'>

# %% [markdown]
# ### Performance
# <img src='http://blog.cloudera.com/wp-content/uploads/2013/01/performance.png'>

# %% [markdown]
# source: http://blog.cloudera.com/blog/2013/01/a-guide-to-python-frameworks-for-hadoop/

# %% [markdown]
# Please download and uncompress these files for the next LAB
#
# https://hpc-forge.cineca.it/files/CoursesDev/public/2015/Tools_Techniques_Data_Analysis/files/

# %% [markdown]
# # End of Chapter
